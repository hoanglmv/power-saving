# %%
# --- Cell 1: Tải các thư viện ---
import pandas as pd
import numpy as np
import catboost
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import joblib
# Cấu hình hiển thị
pd.set_option('display.max_columns', None)
print(f"CatBoost version: {catboost.__version__}")
# Out:
# CatBoost version: 1.2.8

# %%
# --- Cell 2: Tải dữ liệu đã xử lý ---
file_name = '/kaggle/input/kpi-processed/kpi_processed.csv'
try:
    df = pd.read_csv(file_name, index_col=0, parse_dates=True)
    print(f"Tải file '{file_name}' thành công.")
    print(f"Dữ liệu có {len(df)} hàng, kéo dài từ {df.index.min()} đến {df.index.max()}.")
    df.info()
except Exception as e:
    print(f"LỖI: Không thể tải file '{file_name}'.")
    print(e)
# Out:
# Tải file '/kaggle/input/kpi-processed/kpi_processed.csv' thành công.
# Dữ liệu có 313186 hàng, kéo dài từ 2025-10-11 00:00:00 đến 2025-11-10 23:45:00.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 313186 entries, 2025-10-11 00:00:00 to 2025-11-10 23:00:00
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   enodeb                  313186 non-null  object
#  1   cell_name               313186 non-null  object
#  2   ps_traffic_mb           313168 non-null  float64
#  3   avg_rrc_connected_user  313186 non-null  float64
#  4   prb_dl_used             312997 non-null  float64
#  5   prb_dl_available_total  312997 non-null  float64
#  6   prb_utilization         313186 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 19.1+ MB

# %%
# --- Cell 3: Xử lý dữ liệu ---
if 'df' in locals():
    FEATURE_COLS = ['ps_traffic_mb', 'avg_rrc_connected_user', 'prb_dl_used', 'prb_dl_available_total', 'prb_utilization']
    N_FEATURES = len(FEATURE_COLS)
    print(f"Dự đoán {N_FEATURES} features: {FEATURE_COLS}")
    print("Đang xử lý: Đảm bảo dữ liệu 15 phút đầy đủ cho mỗi cell...")
    all_cells = df['cell_name'].unique()
    full_time_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='15min')
    multi_index = pd.MultiIndex.from_product([all_cells, full_time_index], names=['cell_name', 'timestamp'])
    df_data_only = df[FEATURE_COLS + ['cell_name']]
    df_data_only = df_data_only.reset_index()
    print(f"Dữ liệu trước khi xử lý trùng lặp: {len(df_data_only)} hàng")
    df_grouped_unique = df_data_only.groupby(['cell_name', 'timestamp']).mean()
    print(f"Dữ liệu sau khi xử lý trùng lặp (groupby.mean): {len(df_grouped_unique)} hàng")
    df_full = df_grouped_unique.reindex(multi_index, fill_value=0)
    df_full = df_full.reset_index()
    df_full = df_full.set_index('timestamp')
    print(f"Dữ liệu gốc có {len(df)} hàng.")
    print(f"Dữ liệu đã điền đầy đủ (sau reindex) có {len(df_full)} hàng.")
    print("Hoàn tất xử lý.")
    print("\n5 dòng đầu của dữ liệu đã xử lý đầy đủ:")
    print(df_full.head())
else:
    print("Lỗi: DataFrame 'df' không tồn tại. Vui lòng chạy lại Cell 2.")
# Out:
# Dự đoán 5 features: ['ps_traffic_mb', 'avg_rrc_connected_user', 'prb_dl_used', 'prb_dl_available_total', 'prb_utilization']
# Đang xử lý: Đảm bảo dữ liệu 15 phút đầy đủ cho mỗi cell...
# Dữ liệu trước khi xử lý trùng lặp: 313186 hàng
# Dữ liệu sau khi xử lý trùng lặp (groupby.mean): 303370 hàng
# Dữ liệu gốc có 313186 hàng.
# Dữ liệu đã điền đầy đủ (sau reindex) có 321408 hàng.
# Hoàn tất xử lý.
#
# 5 dòng đầu của dữ liệu đã xử lý đầy đủ:
#                     cell_name  ps_traffic_mb  avg_rrc_connected_user  \
# timestamp
# 2025-10-11 00:00:00  EnodebA3         161.14                8.527778
# 2025-10-11 00:15:00  EnodebA3           0.00                0.000000
# 2025-10-11 00:30:00  EnodebA3           0.00                0.000000
# 2025-10-11 00:45:00  EnodebA3           0.00                0.000000
# 2025-10-11 01:00:00  EnodebA3         231.61                7.777778
#
#                      prb_dl_used  prb_dl_available_total  prb_utilization
# timestamp
# 2025-10-11 00:00:00         67.5                    15.0            450.0
# 2025-10-11 00:15:00          0.0                     0.0              0.0
# 2025-10-11 00:30:00          0.0                     0.0              0.0
# 2025-10-11 00:45:00          0.0                     0.0              0.0
# 2025-10-11 01:00:00         67.5                    15.0            450.0

# %%
# --- Cell 4: Chia dữ liệu và Cấu hình mô hình ---
TIMESTEPS_PER_HOUR = 4
TIMESTEPS_PER_DAY = 24 * TIMESTEPS_PER_HOUR
INPUT_DAYS = 2
INPUT_STEPS = INPUT_DAYS * TIMESTEPS_PER_DAY
OUTPUT_DAYS = 1
OUTPUT_STEPS = OUTPUT_DAYS * TIMESTEPS_PER_DAY
print(f"Cấu hình mô hình: Input {INPUT_STEPS} bước (2 ngày), Output {OUTPUT_STEPS} bước (1 ngày).")

if 'df_full' in locals():
    total_duration = df_full.index.max() - df_full.index.min()
    train_end_time = df_full.index.min() + total_duration * 0.7
    val_end_time = df_full.index.min() + total_duration * 0.9
    
    train_df = df_full[df_full.index < train_end_time]
    val_df = df_full[(df_full.index >= train_end_time) & (df_full.index < val_end_time)]
    test_df = df_full[df_full.index >= val_end_time]
    
    print(f"Kích thước tập Train: {train_df.shape}")
    print(f"Kích thước tập Val:   {val_df.shape}")
    print(f"Kích thước tập Test:  {test_df.shape}")
else:
    print("Lỗi: DataFrame 'df_full' không tồn tại.")
# Out:
# Cấu hình mô hình: Input 192 bước (2 ngày), Output 96 bước (1 ngày).
# Kích thước tập Train: (224964, 6)
# Kích thước tập Val:   (64260, 6)
# Kích thước tập Test:  (32184, 6)

# %%
# --- Cell 5: Chuẩn hóa (Scaling) Dữ liệu ---
if 'train_df' in locals():
    train_df = train_df.replace([np.inf, -np.inf], 0).fillna(0)
    val_df = val_df.replace([np.inf, -np.inf], 0).fillna(0)
    test_df = test_df.replace([np.inf, -np.inf], 0).fillna(0)

    scaler = MinMaxScaler()
    scaler.fit(train_df[FEATURE_COLS])

    joblib.dump(scaler, 'scaler.gz')

    train_cells = train_df['cell_name']
    val_cells = val_df['cell_name']
    test_cells = test_df['cell_name']

    train_scaled_data = scaler.transform(train_df[FEATURE_COLS])
    val_scaled_data = scaler.transform(val_df[FEATURE_COLS])
    test_scaled_data = scaler.transform(test_df[FEATURE_COLS])

    scaled_train_df = pd.DataFrame(train_scaled_data, columns=FEATURE_COLS, index=train_df.index)
    scaled_train_df['cell_name'] = train_cells

    scaled_val_df = pd.DataFrame(val_scaled_data, columns=FEATURE_COLS, index=val_df.index)
    scaled_val_df['cell_name'] = val_cells

    scaled_test_df = pd.DataFrame(test_scaled_data, columns=FEATURE_COLS, index=test_df.index)
    scaled_test_df['cell_name'] = test_cells
    
    print("Hoàn tất scaling dữ liệu và lưu scaler vào 'scaler.gz'.")
else:
    print("Lỗi: DataFrame 'train_df' không tồn tại.")
# Out:
# Hoàn tất scaling dữ liệu và lưu scaler vào 'scaler.gz'.

# %%
# --- Cell 6: Hàm tạo cửa sổ (Windowing) ---
def create_windows(data_df, input_steps, output_steps, feature_cols):
    X, y = [], []
    grouped = data_df.groupby('cell_name')
    total_cells = len(grouped)
    print(f"Bắt đầu tạo cửa sổ cho {total_cells} cell...")
    
    for cell_id, cell_data in grouped:
        cell_features = cell_data[feature_cols].values
        total_samples = len(cell_features)
        total_window_len = input_steps + output_steps
        
        for i in range(total_samples - total_window_len + 1):
            input_end = i + input_steps
            output_end = input_end + output_steps
            
            window_X = cell_features[i:input_end, :]
            window_y = cell_features[input_end:output_end, :]
            
            X.append(window_X)
            y.append(window_y)
            
    print(f"Hoàn tất tạo cửa sổ. Đã tạo {len(X)} mẫu.")
    return np.array(X), np.array(y)

# %%
# --- Cell 7: Áp dụng hàm Windowing và làm phẳng dữ liệu ---
if 'scaled_train_df' in locals():
    print("--- Đang tạo mẫu Train ---")
    X_train, y_train = create_windows(scaled_train_df, INPUT_STEPS, OUTPUT_STEPS, FEATURE_COLS)
    print("\n--- Đang tạo mẫu Validation ---")
    X_val, y_val = create_windows(scaled_val_df, INPUT_STEPS, OUTPUT_STEPS, FEATURE_COLS)
    print("\n--- Đang tạo mẫu Test ---")
    X_test, y_test = create_windows(scaled_test_df, INPUT_STEPS, OUTPUT_STEPS, FEATURE_COLS)

    # Làm phẳng dữ liệu (Flatten)
    X_train_flat = X_train.reshape(X_train.shape[0], -1)
    y_train_flat = y_train.reshape(y_train.shape[0], -1)
    X_val_flat = X_val.reshape(X_val.shape[0], -1)
    y_val_flat = y_val.reshape(y_val.shape[0], -1)
    X_test_flat = X_test.reshape(X_test.shape[0], -1)
    # y_test sẽ được giữ nguyên dạng 3D để so sánh với kết quả sau khi reshape lại

    print("\n--- Kích thước dữ liệu sau khi làm phẳng ---")
    print(f"X_train_flat shape: {X_train_flat.shape}")
    print(f"y_train_flat shape: {y_train_flat.shape}")
    print(f"X_val_flat shape:   {X_val_flat.shape}")
    print(f"y_val_flat shape:   {y_val_flat.shape}")
    print(f"X_test_flat shape:  {X_test_flat.shape}")
    print(f"y_test shape:       {y_test.shape}")
else:
    print("Lỗi: Dữ liệu đã scale không tồn tại.")
# Out:
# --- Đang tạo mẫu Train ---
# Bắt đầu tạo cửa sổ cho 108 cell...
# Hoàn tất tạo cửa sổ. Đã tạo 193968 mẫu.
#
# --- Đang tạo mẫu Validation ---
# Bắt đầu tạo cửa sổ cho 108 cell...
# Hoàn tất tạo cửa sổ. Đã tạo 33264 mẫu.
#
# --- Đang tạo mẫu Test ---
# Bắt đầu tạo cửa sổ cho 108 cell...
# Hoàn tất tạo cửa sổ. Đã tạo 1188 mẫu.
#
# --- Kích thước dữ liệu sau khi làm phẳng ---
# X_train_flat shape: (193968, 960)
# y_train_flat shape: (193968, 480)
# X_val_flat shape:   (33264, 960)
# y_val_flat shape:   (33264, 480)
# X_test_flat shape:  (1188, 960)
# y_test shape:       (1188, 96, 5)

# %%
# --- Cell 8: Xây dựng và Huấn luyện mô hình CatBoost (GPU) với Early Stopping ---

from catboost import CatBoostRegressor, Pool
from catboost.utils import get_gpu_device_count
import joblib
import numpy as np

# --- Kiểm tra GPU ---
gpu_count = get_gpu_device_count()
print("CatBoost GPU detected:", gpu_count)

if gpu_count == 0:
    raise RuntimeError("❌ CatBoost KHÔNG phát hiện GPU. Dừng để tránh train bằng CPU.")

# --- Chuẩn hóa dữ liệu để GPU không bị fallback ---
X_tr = np.ascontiguousarray(X_train_flat.astype(np.float32))
X_val = np.ascontiguousarray(X_val_flat.astype(np.float32))
y_tr = np.ascontiguousarray(y_train_flat.astype(np.float32))
y_val = np.ascontiguousarray(y_val_flat.astype(np.float32))

print("Bắt đầu huấn luyện CatBoost GPU với many-output (1 model per output)...")

catboost_models = []
n_outputs = y_tr.shape[1]

for i in range(n_outputs):

    print(f"\n=== Huấn luyện mô hình cho output {i+1}/{n_outputs} ===")

    train_pool = Pool(X_tr, y_tr[:, i])
    eval_pool  = Pool(X_val, y_val[:, i])

    model = CatBoostRegressor(
        iterations = 1000,
        learning_rate = 0.1,
        depth = 6,
        eval_metric = "RMSE",

        # 🔥 BẮT BUỘC: bật GPU
        task_type = "GPU",
        devices = "0",

        # Early stopping
        early_stopping_rounds = 50,

        # Không ghi file để tránh lỗi Kaggle
        allow_writing_files = False,

        random_seed = 42,
        logging_level = "Verbose"
    )

    # Train model với GPU
    model.fit(
        train_pool,
        eval_set = eval_pool,
        verbose = 100
    )

    catboost_models.append(model)

print(f"\nHoàn tất huấn luyện {len(catboost_models)} mô hình CatBoost trên GPU!")

joblib.dump(catboost_models, "catboost_model_gpu.joblib")
print("Đã lưu file 'catboost_model_gpu.joblib'")
# Out:
# CatBoost GPU detected: 2
# Bắt đầu huấn luyện CatBoost GPU với many-output (1 model per output)...
#
# === Huấn luyện mô hình cho output 1/480 ===
# 0:	learn: 0.0577584	test: 0.0573779	best: 0.0573779 (0)	total: 200ms	remaining: 3m 19s
# 100:	learn: 0.0232529	test: 0.0209722	best: 0.0209695 (99)	total: 1.91s	remaining: 17s
# 200:	learn: 0.0223239	test: 0.0208725	best: 0.0208714 (197)	total: 3.43s	remaining: 13.6s
# 300:	learn: 0.0216438	test: 0.0208431	best: 0.0208418 (297)	total: 4.96s	remaining: 11.5s
# 400:	learn: 0.0211271	test: 0.0207883	best: 0.0207841 (392)	total: 6.51s	remaining: 9.73s
# 500:	learn: 0.0207166	test: 0.0207324	best: 0.0207314 (499)	total: 8.14s	remaining: 8.11s
# 600:	learn: 0.0203414	test: 0.0207177	best: 0.0207155 (584)	total: 9.69s	remaining: 6.43s
# 700:	learn: 0.0200117	test: 0.0206990	best: 0.0206979 (699)	total: 11.2s	remaining: 4.79s
# 800:	learn: 0.0197076	test: 0.0206775	best: 0.0206729 (759)	total: 12.8s	remaining: 3.17s
# bestTest = 0.02067287588
# bestIteration = 759
# Shrink model to first 760 iterations.
#
# === Huấn luyện mô hình cho output 2/480 ===
# 0:	learn: 0.0345598	test: 0.0333268	best: 0.0333268 (0)	total: 29.9ms	remaining: 29.9s
# 100:	learn: 0.0090833	test: 0.0066027	best: 0.0066027 (100)	total: 1.71s	remaining: 15.2s
# 200:	learn: 0.0081609	test: 0.0065268	best: 0.0065251 (199)	total: 3.23s	remaining: 12.9s
# 300:	learn: 0.0076595	test: 0.0065155	best: 0.0065100 (285)	total: 4.73s	remaining: 11s
# 400:	learn: 0.0072417	test: 0.0064740	best: 0.0064727 (398)	total: 6.26s	remaining: 9.36s
# 500:	learn: 0.0069428	test: 0.0064501	best: 0.0064431 (485)	total: 7.81s	remaining: 7.78s
# bestTest = 0.006443068918
# bestIteration = 485
# Shrink model to first 486 iterations.
#
# === Huấn luyện mô hình cho output 3/480 ===
# 0:	learn: 0.1678899	test: 0.1757273	best: 0.1757273 (0)	total: 30.9ms	remaining: 30.9s
# 100:	learn: 0.0600111	test: 0.0556393	best: 0.0556393 (100)	total: 1.72s	remaining: 15.3s
# 200:	learn: 0.0567281	test: 0.0552276	best: 0.0552265 (196)	total: 3.29s	remaining: 13.1s
# 300:	learn: 0.0546636	test: 0.0550300	best: 0.0550300 (300)	total: 4.9s	remaining: 11.4s
# 400:	learn: 0.0531906	test: 0.0548093	best: 0.0548093 (400)	total: 6.51s	remaining: 9.72s
# 500:	learn: 0.0521353	test: 0.0546664	best: 0.0546664 (500)	total: 8.08s	remaining: 8.05s
# 600:	learn: 0.0512057	test: 0.0546286	best: 0.0546215 (597)	total: 9.67s	remaining: 6.42s
# 700:	learn: 0.0504168	test: 0.0545774	best: 0.0545774 (700)	total: 11.2s	remaining: 4.8s
# 800:	learn: 0.0496395	test: 0.0545244	best: 0.0545229 (799)	total: 12.8s	remaining: 3.19s
# 900:	learn: 0.0489917	test: 0.0544926	best: 0.0544891 (878)	total: 14.4s	remaining: 1.58s
# bestTest = 0.0544855871
# bestIteration = 903
# Shrink model to first 904 iterations.
#
# === Huấn luyện mô hình cho output 4/480 ===
# 0:	learn: 0.3327363	test: 0.3455919	best: 0.3455919 (0)	total: 32.9ms	remaining: 32.9s
# 100:	learn: 0.0867161	test: 0.1410732	best: 0.1381541 (85)	total: 1.73s	remaining: 15.4s
# 200:	learn: 0.0707780	test: 0.1311234	best: 0.1307715 (195)	total: 3.36s	remaining: 13.4s
# bestTest = 0.1301919647
# bestIteration = 214
# Shrink model to first 215 iterations.
#
# === Huấn luyện mô hình cho output 5/480 ===
# 0:	learn: 0.1678781	test: 0.1757234	best: 0.1757234 (0)	total: 30.7ms	remaining: 30.7s
# 100:	learn: 0.0599173	test: 0.0557982	best: 0.0557982 (100)	total: 1.78s	remaining: 15.9s
# 200:	learn: 0.0568102	test: 0.0553244	best: 0.0553241 (199)	total: 3.37s	remaining: 13.4s
# 300:	learn: 0.0547848	test: 0.0550716	best: 0.0550714 (299)	total: 4.95s	remaining: 11.5s
# 400:	learn: 0.0533532	test: 0.0549461	best: 0.0549456 (399)	total: 6.54s	remaining: 9.77s
# 500:	learn: 0.0522238	test: 0.0548684	best: 0.0548682 (498)	total: 8.15s	remaining: 8.12s
# 600:	learn: 0.0512531	test: 0.0547848	best: 0.0547734 (585)	total: 9.75s	remaining: 6.47s
# 700:	learn: 0.0504573	test: 0.0547105	best: 0.0547000 (695)	total: 11.4s	remaining: 4.85s
# bestTest = 0.05469872407
# bestIteration = 716
# Shrink model to first 717 iterations.
#
# === Huấn luyện mô hình cho output 6/480 ===
# 0:	learn: 0.0580733	test: 0.0575755	best: 0.0575755 (0)	total: 32ms	remaining: 31.9s
# 100:	learn: 0.0257492	test: 0.0233426	best: 0.0233426 (100)	total: 1.75s	remaining: 15.6s
# 200:	learn: 0.0247441	test: 0.0232062	best: 0.0232062 (200)	total: 3.3s	remaining: 13.1s
# 300:	learn: 0.0239198	test: 0.0230992	best: 0.0230958 (295)	total: 4.88s	remaining: 11.3s
# 400:	learn: 0.0233318	test: 0.0230361	best: 0.0230361 (400)	total: 6.46s	remaining: 9.64s
# 500:	learn: 0.0228498	test: 0.0229748	best: 0.0229748 (500)	total: 8.06s	remaining: 8.03s
# 600:	learn: 0.0224303	test: 0.0229398	best: 0.0229392 (599)	total: 9.65s	remaining: 6.41s
# 700:	learn: 0.0220465	test: 0.0229038	best: 0.0229038 (700)	total: 11.3s	remaining: 4.81s
# 800:	learn: 0.0217271	test: 0.0228777	best: 0.0228777 (800)	total: 12.9s	remaining: 3.2s
# 900:	learn: 0.0214140	test: 0.0228510	best: 0.0228510 (900)	total: 14.5s	remaining: 1.59s
# 999:	learn: 0.0211331	test: 0.0228190	best: 0.0228163 (995)	total: 16.1s	remaining: 0us
# bestTest = 0.02281627572
# bestIteration = 995
# Shrink model to first 996 iterations.
#
# === Huấn luyện mô hình cho output 7/480 ===
# 0:	learn: 0.0346569	test: 0.0333562	best: 0.0333562 (0)	total: 33.1ms	remaining: 33.1s
# 100:	learn: 0.0103805	test: 0.0076713	best: 0.0076713 (100)	total: 1.74s	remaining: 15.5s
# 200:	learn: 0.0094795	test: 0.0075822	best: 0.0075817 (197)	total: 3.31s	remaining: 13.2s
# 300:	learn: 0.0089516	test: 0.0075584	best: 0.0075510 (265)	total: 4.9s	remaining: 11.4s
# 400:	learn: 0.0084994	test: 0.0075037	best: 0.0075027 (392)	total: 6.5s	remaining: 9.71s
# 500:	learn: 0.0081743	test: 0.0074762	best: 0.0074753 (498)	total: 8.1s	remaining: 8.06s
# 600:	learn: 0.0078496	test: 0.0074846	best: 0.0074612 (561)	total: 9.74s	remaining: 6.46s
# bestTest = 0.007461243227
# bestIteration = 561
# Shrink model to first 562 iterations.
#
# === Huấn luyện mô hình cho output 8/480 ===
# 0:	learn: 0.1686681	test: 0.1765408	best: 0.1765408 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.0669641	test: 0.0628675	best: 0.0628558 (99)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0636333	test: 0.0622870	best: 0.0622870 (200)	total: 3.47s	remaining: 13.8s
# 300:	learn: 0.0614020	test: 0.0620348	best: 0.0620348 (300)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0598565	test: 0.0619188	best: 0.0619185 (398)	total: 6.77s	remaining: 10.1s
# 500:	learn: 0.0585653	test: 0.0617996	best: 0.0617960 (498)	total: 8.43s	remaining: 8.39s
# 600:	learn: 0.0573773	test: 0.0616965	best: 0.0616939 (595)	total: 10.1s	remaining: 6.71s
# 700:	learn: 0.0563634	test: 0.0616416	best: 0.0616416 (700)	total: 11.8s	remaining: 5.03s
# 800:	learn: 0.0554928	test: 0.0615976	best: 0.0615964 (796)	total: 13.5s	remaining: 3.35s
# 900:	learn: 0.0546985	test: 0.0615204	best: 0.0615204 (900)	total: 15.2s	remaining: 1.67s
# bestTest = 0.06149417885
# bestIteration = 921
# Shrink model to first 922 iterations.
#
# === Huấn luyện mô hình cho output 9/480 ===
# 0:	learn: 0.3326509	test: 0.3455146	best: 0.3455146 (0)	total: 33ms	remaining: 32.9s
# bestTest = 0.1340469803
# bestIteration = 43
# Shrink model to first 44 iterations.
#
# === Huấn luyện mô hình cho output 10/480 ===
# 0:	learn: 0.1686561	test: 0.1765371	best: 0.1765371 (0)	total: 33.2ms	remaining: 33.2s
# 100:	learn: 0.0669400	test: 0.0627462	best: 0.0627462 (100)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0635338	test: 0.0622831	best: 0.0622831 (200)	total: 3.47s	remaining: 13.8s
# 300:	learn: 0.0613715	test: 0.0619936	best: 0.0619936 (300)	total: 5.16s	remaining: 12s
# 400:	learn: 0.0597958	test: 0.0618763	best: 0.0618719 (395)	total: 6.81s	remaining: 10.2s
# 500:	learn: 0.0586184	test: 0.0617541	best: 0.0617521 (494)	total: 8.47s	remaining: 8.43s
# 600:	learn: 0.0574975	test: 0.0616243	best: 0.0616243 (600)	total: 10.1s	remaining: 6.72s
# 700:	learn: 0.0564833	test: 0.0614981	best: 0.0614981 (700)	total: 11.8s	remaining: 5.04s
# 800:	learn: 0.0555862	test: 0.0614427	best: 0.0614385 (793)	total: 13.5s	remaining: 3.36s
# 900:	learn: 0.0547538	test: 0.0614071	best: 0.0613969 (891)	total: 15.3s	remaining: 1.68s
# 999:	learn: 0.0539706	test: 0.0613608	best: 0.0613582 (998)	total: 16.9s	remaining: 0us
# bestTest = 0.06135819975
# bestIteration = 998
# Shrink model to first 999 iterations.
#
# === Huấn luyện mô hình cho output 11/480 ===
# 0:	learn: 0.0582537	test: 0.0577716	best: 0.0577716 (0)	total: 34.3ms	remaining: 34.3s
# 100:	learn: 0.0267710	test: 0.0241646	best: 0.0241646 (100)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0255920	test: 0.0240008	best: 0.0240008 (200)	total: 3.4s	remaining: 13.5s
# 300:	learn: 0.0248005	test: 0.0238723	best: 0.0238723 (300)	total: 5.06s	remaining: 11.8s
# 400:	learn: 0.0241678	test: 0.0237869	best: 0.0237869 (400)	total: 6.71s	remaining: 10s
# 500:	learn: 0.0236767	test: 0.0237274	best: 0.0237267 (497)	total: 8.34s	remaining: 8.3s
# 600:	learn: 0.0232289	test: 0.0237143	best: 0.0237143 (600)	total: 10s	remaining: 6.64s
# 700:	learn: 0.0228075	test: 0.0236927	best: 0.0236865 (689)	total: 11.7s	remaining: 4.99s
# 800:	learn: 0.0224539	test: 0.0236819	best: 0.0236765 (788)	total: 13.4s	remaining: 3.32s
# 900:	learn: 0.0221167	test: 0.0236498	best: 0.0236498 (900)	total: 15s	remaining: 1.65s
# 999:	learn: 0.0218232	test: 0.0236317	best: 0.0236317 (999)	total: 16.7s	remaining: 0us
# bestTest = 0.02363172007
# bestIteration = 999
#
# === Huấn luyện mô hình cho output 12/480 ===
# 0:	learn: 0.0347539	test: 0.0333147	best: 0.0333147 (0)	total: 34.5ms	remaining: 34.5s
# 100:	learn: 0.0112801	test: 0.0081527	best: 0.0081527 (100)	total: 1.74s	remaining: 15.5s
# 200:	learn: 0.0103222	test: 0.0080101	best: 0.0080101 (200)	total: 3.36s	remaining: 13.4s
# 300:	learn: 0.0097028	test: 0.0079466	best: 0.0079466 (300)	total: 4.96s	remaining: 11.5s
# 400:	learn: 0.0092340	test: 0.0078945	best: 0.0078939 (399)	total: 6.59s	remaining: 9.84s
# 500:	learn: 0.0088768	test: 0.0078740	best: 0.0078693 (493)	total: 8.19s	remaining: 8.16s
# 600:	learn: 0.0085533	test: 0.0078591	best: 0.0078583 (573)	total: 9.82s	remaining: 6.52s
# 700:	learn: 0.0082912	test: 0.0078271	best: 0.0078265 (698)	total: 11.5s	remaining: 4.89s
# 800:	learn: 0.0080825	test: 0.0078097	best: 0.0078097 (800)	total: 13.1s	remaining: 3.25s
# 900:	learn: 0.0078736	test: 0.0077905	best: 0.0077896 (884)	total: 14.8s	remaining: 1.62s
# 999:	learn: 0.0077056	test: 0.0077843	best: 0.0077819 (990)	total: 16.4s	remaining: 0us
# bestTest = 0.007781921202
# bestIteration = 990
# Shrink model to first 991 iterations.
#
# === Huấn luyện mô hình cho output 13/480 ===
# 0:	learn: 0.1691652	test: 0.1770922	best: 0.1770922 (0)	total: 34ms	remaining: 34s
# 100:	learn: 0.0703714	test: 0.0653877	best: 0.0653815 (90)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.0666848	test: 0.0648580	best: 0.0648580 (200)	total: 3.46s	remaining: 13.8s
# 300:	learn: 0.0643835	test: 0.0646282	best: 0.0646263 (296)	total: 5.13s	remaining: 11.9s
# 400:	learn: 0.0626368	test: 0.0644530	best: 0.0644489 (395)	total: 6.82s	remaining: 10.2s
# 500:	learn: 0.0610803	test: 0.0642563	best: 0.0642563 (500)	total: 8.53s	remaining: 8.49s
# 600:	learn: 0.0598620	test: 0.0641393	best: 0.0641352 (596)	total: 10.2s	remaining: 6.78s
# 700:	learn: 0.0587742	test: 0.0640767	best: 0.0640767 (700)	total: 11.9s	remaining: 5.07s
# 800:	learn: 0.0577570	test: 0.0640061	best: 0.0640052 (799)	total: 13.6s	remaining: 3.38s
# 900:	learn: 0.0568607	test: 0.0639519	best: 0.0639456 (877)	total: 15.3s	remaining: 1.68s
# bestTest = 0.06393767001
# bestIteration = 925
# Shrink model to first 926 iterations.
#
# === Huấn luyện mô hình cho output 14/480 ===
# 0:	learn: 0.3326929	test: 0.3449762	best: 0.3449762 (0)	total: 34.2ms	remaining: 34.2s
# 100:	learn: 0.0955044	test: 0.1219449	best: 0.1219449 (100)	total: 1.8s	remaining: 16.1s
# bestTest = 0.1215480897
# bestIteration = 104
# Shrink model to first 105 iterations.
#
# === Huấn luyện mô hình cho output 15/480 ===
# 0:	learn: 0.1691519	test: 0.1770876	best: 0.1770876 (0)	total: 33.1ms	remaining: 33.1s
# 100:	learn: 0.0703522	test: 0.0653642	best: 0.0653642 (100)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0667866	test: 0.0648119	best: 0.0648119 (200)	total: 3.5s	remaining: 13.9s
# 300:	learn: 0.0644197	test: 0.0645349	best: 0.0645342 (299)	total: 5.17s	remaining: 12s
# 400:	learn: 0.0626652	test: 0.0643787	best: 0.0643749 (395)	total: 6.83s	remaining: 10.2s
# 500:	learn: 0.0610266	test: 0.0641539	best: 0.0641539 (500)	total: 8.54s	remaining: 8.5s
# 600:	learn: 0.0598683	test: 0.0641114	best: 0.0640942 (594)	total: 10.2s	remaining: 6.78s
# 700:	learn: 0.0587537	test: 0.0640415	best: 0.0640415 (700)	total: 11.9s	remaining: 5.07s
# 800:	learn: 0.0577419	test: 0.0639619	best: 0.0639615 (797)	total: 13.6s	remaining: 3.38s
# 900:	learn: 0.0568605	test: 0.0639462	best: 0.0639230 (874)	total: 15.3s	remaining: 1.68s
# bestTest = 0.06392300374
# bestIteration = 874
# Shrink model to first 875 iterations.
#
# === Huấn luyện mô hình cho output 16/480 ===
# 0:	learn: 0.0582943	test: 0.0578225	best: 0.0578225 (0)	total: 34.1ms	remaining: 34s
# 100:	learn: 0.0275097	test: 0.0245729	best: 0.0245729 (100)	total: 1.78s	remaining: 15.9s
# 200:	learn: 0.0263018	test: 0.0244333	best: 0.0244331 (199)	total: 3.41s	remaining: 13.6s
# 300:	learn: 0.0254289	test: 0.0243105	best: 0.0243105 (300)	total: 5.06s	remaining: 11.7s
# 400:	learn: 0.0247323	test: 0.0242174	best: 0.0242174 (400)	total: 6.71s	remaining: 10s
# 500:	learn: 0.0241939	test: 0.0241932	best: 0.0241932 (500)	total: 8.35s	remaining: 8.31s
# 600:	learn: 0.0236892	test: 0.0241317	best: 0.0241317 (600)	total: 10s	remaining: 6.66s
# 700:	learn: 0.0232827	test: 0.0241069	best: 0.0241037 (685)	total: 11.7s	remaining: 4.99s
# bestTest = 0.02410020267
# bestIteration = 725
# Shrink model to first 726 iterations.
#
# === Huấn luyện mô hình cho output 17/480 ===
# 0:	learn: 0.0348092	test: 0.0333136	best: 0.0333136 (0)	total: 34.9ms	remaining: 34.9s
# 100:	learn: 0.0117637	test: 0.0086273	best: 0.0086273 (100)	total: 1.76s	remaining: 15.7s
# 200:	learn: 0.0107827	test: 0.0085292	best: 0.0085221 (191)	total: 3.36s	remaining: 13.4s
# 300:	learn: 0.0101451	test: 0.0084317	best: 0.0084317 (300)	total: 4.98s	remaining: 11.6s
# 400:	learn: 0.0096045	test: 0.0083975	best: 0.0083972 (399)	total: 6.63s	remaining: 9.91s
# 500:	learn: 0.0092528	test: 0.0083577	best: 0.0083574 (495)	total: 8.26s	remaining: 8.22s
# 600:	learn: 0.0089365	test: 0.0083125	best: 0.0083103 (596)	total: 9.91s	remaining: 6.58s
# 700:	learn: 0.0086558	test: 0.0082814	best: 0.0082814 (700)	total: 11.6s	remaining: 4.94s
# 800:	learn: 0.0084326	test: 0.0082583	best: 0.0082540 (778)	total: 13.2s	remaining: 3.29s
# 900:	learn: 0.0082414	test: 0.0082387	best: 0.0082385 (899)	total: 14.9s	remaining: 1.63s
# 999:	learn: 0.0080639	test: 0.0082208	best: 0.0082208 (999)	total: 16.5s	remaining: 0us
# bestTest = 0.008220831463
# bestIteration = 999
#
# === Huấn luyện mô hình cho output 18/480 ===
# 0:	learn: 0.1693067	test: 0.1772290	best: 0.1772290 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.0718931	test: 0.0666837	best: 0.0666837 (100)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0682346	test: 0.0661768	best: 0.0661737 (199)	total: 3.48s	remaining: 13.8s
# 300:	learn: 0.0658930	test: 0.0659552	best: 0.0659508 (293)	total: 5.15s	remaining: 12s
# 400:	learn: 0.0641442	test: 0.0657154	best: 0.0657154 (400)	total: 6.8s	remaining: 10.2s
# 500:	learn: 0.0626520	test: 0.0656470	best: 0.0656428 (488)	total: 8.46s	remaining: 8.42s
# 600:	learn: 0.0613249	test: 0.0654941	best: 0.0654891 (581)	total: 10.1s	remaining: 6.71s
# 700:	learn: 0.0601590	test: 0.0654184	best: 0.0654184 (700)	total: 11.8s	remaining: 5.03s
# 800:	learn: 0.0591105	test: 0.0653842	best: 0.0653781 (778)	total: 13.5s	remaining: 3.35s
# 900:	learn: 0.0581700	test: 0.0653513	best: 0.0653340 (881)	total: 15.2s	remaining: 1.67s
# bestTest = 0.06533398599
# bestIteration = 881
# Shrink model to first 882 iterations.
#
# === Huấn luyện mô hình cho output 19/480 ===
# 0:	learn: 0.3326549	test: 0.3471968	best: 0.3471968 (0)	total: 33.5ms	remaining: 33.4s
# bestTest = 0.1445130945
# bestIteration = 35
# Shrink model to first 36 iterations.
#
# === Huấn luyện mô hình cho output 20/480 ===
# 0:	learn: 0.1692908	test: 0.1772223	best: 0.1772223 (0)	total: 34.5ms	remaining: 34.4s
# 100:	learn: 0.0721018	test: 0.0667553	best: 0.0667553 (100)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0682092	test: 0.0662730	best: 0.0662651 (198)	total: 3.48s	remaining: 13.8s
# 300:	learn: 0.0658167	test: 0.0660498	best: 0.0660369 (291)	total: 5.14s	remaining: 11.9s
# 400:	learn: 0.0639728	test: 0.0658279	best: 0.0658279 (400)	total: 6.8s	remaining: 10.2s
# 500:	learn: 0.0624919	test: 0.0657003	best: 0.0656971 (495)	total: 8.46s	remaining: 8.42s
# 600:	learn: 0.0611950	test: 0.0656134	best: 0.0655897 (584)	total: 10.1s	remaining: 6.72s
# 700:	learn: 0.0600594	test: 0.0655442	best: 0.0655083 (672)	total: 11.8s	remaining: 5.04s
# bestTest = 0.06550832653
# bestIteration = 672
# Shrink model to first 673 iterations.
#
# === Huấn luyện mô hình cho output 21/480 ===
# 0:	learn: 0.0583876	test: 0.0578674	best: 0.0578674 (0)	total: 32.9ms	remaining: 32.9s
# 100:	learn: 0.0281062	test: 0.0249685	best: 0.0249674 (99)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0267496	test: 0.0247799	best: 0.0247792 (197)	total: 3.43s	remaining: 13.6s
# 300:	learn: 0.0257997	test: 0.0246831	best: 0.0246829 (299)	total: 5.1s	remaining: 11.8s
# 400:	learn: 0.0251105	test: 0.0246333	best: 0.0246333 (400)	total: 6.78s	remaining: 10.1s
# 500:	learn: 0.0245156	test: 0.0245735	best: 0.0245673 (493)	total: 8.46s	remaining: 8.42s
# bestTest = 0.02456733011
# bestIteration = 493
# Shrink model to first 494 iterations.
#
# === Huấn luyện mô hình cho output 22/480 ===
# 0:	learn: 0.0348251	test: 0.0333030	best: 0.0333030 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.0122798	test: 0.0089726	best: 0.0089726 (100)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0113194	test: 0.0088511	best: 0.0088491 (199)	total: 3.41s	remaining: 13.5s
# 300:	learn: 0.0106311	test: 0.0087840	best: 0.0087840 (300)	total: 5.04s	remaining: 11.7s
# 400:	learn: 0.0101074	test: 0.0087422	best: 0.0087413 (399)	total: 6.69s	remaining: 9.99s
# bestTest = 0.008736379992
# bestIteration = 406
# Shrink model to first 407 iterations.
#
# === Huấn luyện mô hình cho output 23/480 ===
# 0:	learn: 0.1694791	test: 0.1774710	best: 0.1774710 (0)	total: 33.3ms	remaining: 33.2s
# 100:	learn: 0.0733765	test: 0.0680208	best: 0.0680208 (100)	total: 1.83s	remaining: 16.3s
# 200:	learn: 0.0697199	test: 0.0675225	best: 0.0675225 (200)	total: 3.5s	remaining: 13.9s
# 300:	learn: 0.0672958	test: 0.0672686	best: 0.0672598 (298)	total: 5.17s	remaining: 12s
# 400:	learn: 0.0654971	test: 0.0670335	best: 0.0670335 (400)	total: 6.82s	remaining: 10.2s
# 500:	learn: 0.0638169	test: 0.0668549	best: 0.0668549 (500)	total: 8.52s	remaining: 8.49s
# 600:	learn: 0.0624331	test: 0.0667833	best: 0.0667833 (600)	total: 10.2s	remaining: 6.77s
# 700:	learn: 0.0611925	test: 0.0666577	best: 0.0666577 (700)	total: 11.9s	remaining: 5.07s
# 800:	learn: 0.0601342	test: 0.0665902	best: 0.0665902 (800)	total: 13.6s	remaining: 3.38s
# 900:	learn: 0.0591393	test: 0.0665209	best: 0.0665122 (896)	total: 15.3s	remaining: 1.68s
# bestTest = 0.06648991578
# bestIteration = 926
# Shrink model to first 927 iterations.
#
# === Huấn luyện mô hình cho output 24/480 ===
# 0:	learn: 0.3325785	test: 0.3465858	best: 0.3465858 (0)	total: 33.8ms	remaining: 33.8s
# bestTest = 0.1514980923
# bestIteration = 27
# Shrink model to first 28 iterations.
#
# === Huấn luyện mô hình cho output 25/480 ===
# 0:	learn: 0.1694649	test: 0.1774655	best: 0.1774655 (0)	total: 32.9ms	remaining: 32.9s
# 100:	learn: 0.0733147	test: 0.0680889	best: 0.0680889 (100)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.0696669	test: 0.0674486	best: 0.0674486 (200)	total: 3.46s	remaining: 13.7s
# 300:	learn: 0.0671693	test: 0.0672397	best: 0.0672397 (300)	total: 5.1s	remaining: 11.8s
# 400:	learn: 0.0652843	test: 0.0670095	best: 0.0670083 (399)	total: 6.74s	remaining: 10.1s
# 500:	learn: 0.0636851	test: 0.0668758	best: 0.0668658 (497)	total: 8.41s	remaining: 8.38s
# 600:	learn: 0.0622977	test: 0.0668073	best: 0.0668057 (599)	total: 10.1s	remaining: 6.71s
# 700:	learn: 0.0611174	test: 0.0667106	best: 0.0667106 (700)	total: 11.8s	remaining: 5.02s
# 800:	learn: 0.0600246	test: 0.0666524	best: 0.0666512 (798)	total: 13.5s	remaining: 3.34s
# bestTest = 0.06665122705
# bestIteration = 798
# Shrink model to first 799 iterations.
#
# === Huấn luyện mô hình cho output 26/480 ===
# 0:	learn: 0.0584412	test: 0.0579263	best: 0.0579263 (0)	total: 32.8ms	remaining: 32.8s
# 100:	learn: 0.0285228	test: 0.0253543	best: 0.0253543 (100)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0270970	test: 0.0251050	best: 0.0251050 (200)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0261212	test: 0.0250365	best: 0.0250365 (300)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0254075	test: 0.0249602	best: 0.0249589 (394)	total: 6.79s	remaining: 10.1s
# 500:	learn: 0.0248367	test: 0.0249035	best: 0.0249035 (500)	total: 8.46s	remaining: 8.42s
# 600:	learn: 0.0243264	test: 0.0248551	best: 0.0248537 (598)	total: 10.1s	remaining: 6.74s
# 700:	learn: 0.0238993	test: 0.0248328	best: 0.0248272 (687)	total: 11.9s	remaining: 5.05s
# bestTest = 0.02482717298
# bestIteration = 687
# Shrink model to first 688 iterations.
#
# === Huấn luyện mô hình cho output 27/480 ===
# 0:	learn: 0.0349040	test: 0.0332996	best: 0.0332996 (0)	total: 35.6ms	remaining: 35.6s
# 100:	learn: 0.0126799	test: 0.0093604	best: 0.0093604 (100)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0115687	test: 0.0092037	best: 0.0092037 (200)	total: 3.44s	remaining: 13.7s
# 300:	learn: 0.0108915	test: 0.0091161	best: 0.0091148 (298)	total: 5.06s	remaining: 11.7s
# 400:	learn: 0.0103460	test: 0.0090386	best: 0.0090386 (400)	total: 6.71s	remaining: 10s
# 500:	learn: 0.0099241	test: 0.0089805	best: 0.0089805 (500)	total: 8.35s	remaining: 8.32s
# bestTest = 0.008968944107
# bestIteration = 528
# Shrink model to first 529 iterations.
#
# === Huấn luyện mô hình cho output 28/480 ===
# 0:	learn: 0.1697364	test: 0.1774086	best: 0.1774086 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.0744527	test: 0.0688524	best: 0.0688524 (100)	total: 1.8s	remaining: 16.1s
# 200:	learn: 0.0705850	test: 0.0682195	best: 0.0682195 (200)	total: 3.47s	remaining: 13.8s
# 300:	learn: 0.0680802	test: 0.0679327	best: 0.0679327 (300)	total: 5.13s	remaining: 11.9s
# 400:	learn: 0.0660824	test: 0.0677678	best: 0.0677663 (399)	total: 6.79s	remaining: 10.1s
# 500:	learn: 0.0644554	test: 0.0675975	best: 0.0675864 (490)	total: 8.46s	remaining: 8.43s
# 600:	learn: 0.0631299	test: 0.0675038	best: 0.0674922 (595)	total: 10.1s	remaining: 6.73s
# 700:	learn: 0.0618415	test: 0.0673376	best: 0.0673349 (698)	total: 11.8s	remaining: 5.05s
# 800:	learn: 0.0607446	test: 0.0672898	best: 0.0672799 (754)	total: 13.5s	remaining: 3.36s
# bestTest = 0.06727985341
# bestIteration = 754
# Shrink model to first 755 iterations.
#
# === Huấn luyện mô hình cho output 29/480 ===
# 0:	learn: 0.3324790	test: 0.3483062	best: 0.3483062 (0)	total: 33.4ms	remaining: 33.4s
# 100:	learn: 0.1003035	test: 0.1479726	best: 0.1469978 (97)	total: 1.81s	remaining: 16.1s
# bestTest = 0.1469978325
# bestIteration = 97
# Shrink model to first 98 iterations.
#
# === Huấn luyện mô hình cho output 30/480 ===
# 0:	learn: 0.1697216	test: 0.1774024	best: 0.1774024 (0)	total: 35.4ms	remaining: 35.4s
# 100:	learn: 0.0744226	test: 0.0688400	best: 0.0688400 (100)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0705742	test: 0.0681502	best: 0.0681481 (199)	total: 3.48s	remaining: 13.8s
# 300:	learn: 0.0680560	test: 0.0678036	best: 0.0677730 (291)	total: 5.14s	remaining: 11.9s
# 400:	learn: 0.0659960	test: 0.0675754	best: 0.0675754 (399)	total: 6.82s	remaining: 10.2s
# 500:	learn: 0.0644219	test: 0.0674296	best: 0.0674250 (497)	total: 8.49s	remaining: 8.46s
# 600:	learn: 0.0631095	test: 0.0673399	best: 0.0673345 (599)	total: 10.2s	remaining: 6.76s
# 700:	learn: 0.0618932	test: 0.0672637	best: 0.0672489 (681)	total: 11.9s	remaining: 5.06s
# bestTest = 0.06724892301
# bestIteration = 681
# Shrink model to first 682 iterations.
#
# === Huấn luyện mô hình cho output 31/480 ===
# 0:	learn: 0.0585118	test: 0.0578989	best: 0.0578989 (0)	total: 33.5ms	remaining: 33.5s
# 100:	learn: 0.0287858	test: 0.0255728	best: 0.0255728 (100)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.0273630	test: 0.0253523	best: 0.0253523 (200)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0264439	test: 0.0252347	best: 0.0252346 (299)	total: 5.11s	remaining: 11.9s
# 400:	learn: 0.0257001	test: 0.0251597	best: 0.0251562 (398)	total: 6.77s	remaining: 10.1s
# 500:	learn: 0.0250748	test: 0.0251116	best: 0.0251094 (498)	total: 8.45s	remaining: 8.41s
# 600:	learn: 0.0245644	test: 0.0250728	best: 0.0250707 (597)	total: 10.1s	remaining: 6.73s
# 700:	learn: 0.0241143	test: 0.0250240	best: 0.0250240 (700)	total: 11.8s	remaining: 5.04s
# 800:	learn: 0.0237263	test: 0.0250040	best: 0.0250024 (764)	total: 13.5s	remaining: 3.36s
# 900:	learn: 0.0233868	test: 0.0249799	best: 0.0249732 (891)	total: 15.2s	remaining: 1.67s
# 999:	learn: 0.0230522	test: 0.0249637	best: 0.0249614 (982)	total: 16.9s	remaining: 0us
# bestTest = 0.02496141899
# bestIteration = 982
# Shrink model to first 983 iterations.
#
# === Huấn luyện mô hình cho output 32/480 ===
# 0:	learn: 0.0349075	test: 0.0333174	best: 0.0333174 (0)	total: 33ms	remaining: 32.9s
# 100:	learn: 0.0128924	test: 0.0095286	best: 0.0095286 (100)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0117679	test: 0.0093490	best: 0.0093490 (200)	total: 3.4s	remaining: 13.5s
# 300:	learn: 0.0110968	test: 0.0092902	best: 0.0092843 (291)	total: 5s	remaining: 11.6s
# 400:	learn: 0.0105282	test: 0.0092219	best: 0.0092219 (400)	total: 6.64s	remaining: 9.93s
# 500:	learn: 0.0101349	test: 0.0091653	best: 0.0091651 (495)	total: 8.26s	remaining: 8.23s
# 600:	learn: 0.0097868	test: 0.0091323	best: 0.0091298 (595)	total: 9.88s	remaining: 6.56s
# 700:	learn: 0.0094862	test: 0.0090881	best: 0.0090874 (698)	total: 11.5s	remaining: 4.92s
# 800:	learn: 0.0092344	test: 0.0090485	best: 0.0090485 (800)	total: 13.2s	remaining: 3.27s
# 900:	learn: 0.0089924	test: 0.0090032	best: 0.0090021 (897)	total: 14.8s	remaining: 1.63s
# 999:	learn: 0.0087926	test: 0.0089895	best: 0.0089873 (982)	total: 16.5s	remaining: 0us
# bestTest = 0.008987268908
# bestIteration = 982
# Shrink model to first 983 iterations.
#
# === Huấn luyện mô hình cho output 33/480 ===
# 0:	learn: 0.1698083	test: 0.1770590	best: 0.1770590 (0)	total: 33.2ms	remaining: 33.1s
# 100:	learn: 0.0750604	test: 0.0694365	best: 0.0694365 (100)	total: 1.79s	remaining: 16s
# 200:	learn: 0.0710684	test: 0.0686541	best: 0.0686541 (200)	total: 3.44s	remaining: 13.7s
# 300:	learn: 0.0682905	test: 0.0683352	best: 0.0683352 (300)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0665006	test: 0.0682281	best: 0.0682134 (394)	total: 6.76s	remaining: 10.1s
# 500:	learn: 0.0648975	test: 0.0681678	best: 0.0681515 (494)	total: 8.41s	remaining: 8.38s
# 600:	learn: 0.0635684	test: 0.0679705	best: 0.0679671 (597)	total: 10.1s	remaining: 6.69s
# 700:	learn: 0.0623397	test: 0.0678752	best: 0.0678720 (697)	total: 11.8s	remaining: 5.01s
# 800:	learn: 0.0612040	test: 0.0678095	best: 0.0678039 (790)	total: 13.4s	remaining: 3.34s
# 900:	learn: 0.0602636	test: 0.0677742	best: 0.0677742 (900)	total: 15.1s	remaining: 1.66s
# bestTest = 0.06774640778
# bestIteration = 933
# Shrink model to first 934 iterations.
#
# === Huấn luyện mô hình cho output 34/480 ===
# 0:	learn: 0.3323930	test: 0.3482362	best: 0.3482362 (0)	total: 32.7ms	remaining: 32.6s
# 100:	learn: 0.1022131	test: 0.1407217	best: 0.1384737 (70)	total: 1.79s	remaining: 16s
# bestTest = 0.1384737468
# bestIteration = 70
# Shrink model to first 71 iterations.
#
# === Huấn luyện mô hình cho output 35/480 ===
# 0:	learn: 0.1697934	test: 0.1770528	best: 0.1770528 (0)	total: 33.1ms	remaining: 33.1s
# 100:	learn: 0.0749723	test: 0.0692933	best: 0.0692933 (100)	total: 1.8s	remaining: 16s
# 200:	learn: 0.0710761	test: 0.0687135	best: 0.0687135 (200)	total: 3.46s	remaining: 13.7s
# 300:	learn: 0.0683005	test: 0.0684420	best: 0.0684420 (300)	total: 5.14s	remaining: 11.9s
# 400:	learn: 0.0664691	test: 0.0683833	best: 0.0683767 (395)	total: 6.8s	remaining: 10.2s
# 500:	learn: 0.0649322	test: 0.0682694	best: 0.0682694 (500)	total: 8.49s	remaining: 8.46s
# 600:	learn: 0.0635226	test: 0.0680631	best: 0.0680559 (595)	total: 10.2s	remaining: 6.76s
# 700:	learn: 0.0622784	test: 0.0679676	best: 0.0679552 (697)	total: 11.9s	remaining: 5.07s
# 800:	learn: 0.0611466	test: 0.0679162	best: 0.0679121 (799)	total: 13.6s	remaining: 3.37s
# 900:	learn: 0.0601935	test: 0.0678150	best: 0.0678150 (900)	total: 15.3s	remaining: 1.68s
# 999:	learn: 0.0592885	test: 0.0677562	best: 0.0677548 (996)	total: 16.9s	remaining: 0us
# bestTest = 0.06775477634
# bestIteration = 996
# Shrink model to first 997 iterations.
#
# === Huấn luyện mô hình cho output 36/480 ===
# 0:	learn: 0.0585703	test: 0.0578241	best: 0.0578241 (0)	total: 34.5ms	remaining: 34.4s
# 100:	learn: 0.0289876	test: 0.0257633	best: 0.0257633 (100)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0275756	test: 0.0256139	best: 0.0256139 (200)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0265563	test: 0.0254665	best: 0.0254665 (300)	total: 5.14s	remaining: 11.9s
# 400:	learn: 0.0258281	test: 0.0253747	best: 0.0253738 (399)	total: 6.8s	remaining: 10.2s
# 500:	learn: 0.0252059	test: 0.0253384	best: 0.0253344 (498)	total: 8.49s	remaining: 8.45s
# 600:	learn: 0.0246828	test: 0.0252616	best: 0.0252616 (600)	total: 10.2s	remaining: 6.75s
# 700:	learn: 0.0242353	test: 0.0252154	best: 0.0252152 (683)	total: 11.8s	remaining: 5.05s
# 800:	learn: 0.0238525	test: 0.0251904	best: 0.0251842 (778)	total: 13.5s	remaining: 3.36s
# 900:	learn: 0.0234825	test: 0.0251531	best: 0.0251527 (898)	total: 15.2s	remaining: 1.67s
# 999:	learn: 0.0231445	test: 0.0251497	best: 0.0251452 (988)	total: 16.9s	remaining: 0us
# bestTest = 0.02514520684
# bestIteration = 988
# Shrink model to first 989 iterations.
#
# === Huấn luyện mô hình cho output 37/480 ===
# 0:	learn: 0.0349493	test: 0.0333308	best: 0.0333308 (0)	total: 35.7ms	remaining: 35.7s
# 100:	learn: 0.0130537	test: 0.0096677	best: 0.0096677 (100)	total: 1.76s	remaining: 15.7s
# 200:	learn: 0.0120032	test: 0.0095337	best: 0.0095335 (196)	total: 3.37s	remaining: 13.4s
# 300:	learn: 0.0112714	test: 0.0094047	best: 0.0094047 (300)	total: 4.98s	remaining: 11.6s
# 400:	learn: 0.0107069	test: 0.0093469	best: 0.0093450 (379)	total: 6.61s	remaining: 9.87s
# 500:	learn: 0.0102535	test: 0.0093075	best: 0.0093052 (498)	total: 8.25s	remaining: 8.21s
# 600:	learn: 0.0099013	test: 0.0092857	best: 0.0092848 (599)	total: 9.89s	remaining: 6.57s
# 700:	learn: 0.0096136	test: 0.0092558	best: 0.0092516 (689)	total: 11.5s	remaining: 4.92s
# 800:	learn: 0.0093674	test: 0.0092335	best: 0.0092317 (788)	total: 13.2s	remaining: 3.28s
# 900:	learn: 0.0091341	test: 0.0092005	best: 0.0091986 (898)	total: 14.9s	remaining: 1.63s
# 999:	learn: 0.0089388	test: 0.0091774	best: 0.0091770 (998)	total: 16.5s	remaining: 0us
# bestTest = 0.009177033518
# bestIteration = 998
# Shrink model to first 999 iterations.
#
# === Huấn luyện mô hình cho output 38/480 ===
# 0:	learn: 0.1700341	test: 0.1768780	best: 0.1768780 (0)	total: 34.2ms	remaining: 34.1s
# 100:	learn: 0.0754592	test: 0.0696213	best: 0.0696213 (100)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0716468	test: 0.0691311	best: 0.0691311 (200)	total: 3.46s	remaining: 13.8s
# 300:	learn: 0.0689378	test: 0.0688072	best: 0.0688045 (298)	total: 5.13s	remaining: 11.9s
# 400:	learn: 0.0669308	test: 0.0686120	best: 0.0686120 (400)	total: 6.81s	remaining: 10.2s
# 500:	learn: 0.0652496	test: 0.0684984	best: 0.0684984 (500)	total: 8.48s	remaining: 8.45s
# 600:	learn: 0.0638283	test: 0.0684528	best: 0.0684196 (561)	total: 10.2s	remaining: 6.75s
# bestTest = 0.06841960103
# bestIteration = 561
# Shrink model to first 562 iterations.
#
# === Huấn luyện mô hình cho output 39/480 ===
# 0:	learn: 0.3327191	test: 0.3484678	best: 0.3484678 (0)	total: 34.2ms	remaining: 34.2s
# 100:	learn: 0.1010454	test: 0.1468616	best: 0.1461918 (94)	total: 1.82s	remaining: 16.2s
# bestTest = 0.1461431373
# bestIteration = 110
# Shrink model to first 111 iterations.
#
# === Huấn luyện mô hình cho output 40/480 ===
# 0:	learn: 0.1700194	test: 0.1768723	best: 0.1768723 (0)	total: 34.3ms	remaining: 34.3s
# 100:	learn: 0.0753746	test: 0.0697506	best: 0.0697506 (100)	total: 1.81s	remaining: 16.2s
# 200:	learn: 0.0714449	test: 0.0692330	best: 0.0692286 (189)	total: 3.5s	remaining: 13.9s
# 300:	learn: 0.0690260	test: 0.0690186	best: 0.0690021 (291)	total: 5.17s	remaining: 12s
# 400:	learn: 0.0669845	test: 0.0687925	best: 0.0687925 (400)	total: 6.87s	remaining: 10.3s
# 500:	learn: 0.0652338	test: 0.0685536	best: 0.0685473 (496)	total: 8.58s	remaining: 8.54s
# 600:	learn: 0.0638083	test: 0.0684670	best: 0.0684670 (600)	total: 10.3s	remaining: 6.82s
# 700:	learn: 0.0625995	test: 0.0683504	best: 0.0683504 (700)	total: 12s	remaining: 5.1s
# bestTest = 0.06833232679
# bestIteration = 716
# Shrink model to first 717 iterations.
#
# === Huấn luyện mô hình cho output 41/480 ===
# 0:	learn: 0.0586059	test: 0.0577168	best: 0.0577168 (0)	total: 33.6ms	remaining: 33.5s
# 100:	learn: 0.0292132	test: 0.0259930	best: 0.0259930 (100)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.0277174	test: 0.0257394	best: 0.0257394 (200)	total: 3.44s	remaining: 13.7s
# 300:	learn: 0.0267225	test: 0.0256328	best: 0.0256328 (300)	total: 5.11s	remaining: 11.9s
# 400:	learn: 0.0259611	test: 0.0255824	best: 0.0255809 (353)	total: 6.78s	remaining: 10.1s
# 500:	learn: 0.0253386	test: 0.0255180	best: 0.0255132 (472)	total: 8.47s	remaining: 8.44s
# 600:	learn: 0.0248140	test: 0.0254552	best: 0.0254552 (600)	total: 10.2s	remaining: 6.74s
# 700:	learn: 0.0243648	test: 0.0254182	best: 0.0254181 (697)	total: 11.8s	remaining: 5.05s
# bestTest = 0.02540672047
# bestIteration = 713
# Shrink model to first 714 iterations.
#
# === Huấn luyện mô hình cho output 42/480 ===
# 0:	learn: 0.0349717	test: 0.0332952	best: 0.0332952 (0)	total: 33.7ms	remaining: 33.7s
# 100:	learn: 0.0132516	test: 0.0099443	best: 0.0099421 (98)	total: 1.74s	remaining: 15.4s
# 200:	learn: 0.0121624	test: 0.0097780	best: 0.0097775 (199)	total: 3.34s	remaining: 13.3s
# 300:	learn: 0.0113929	test: 0.0096686	best: 0.0096686 (300)	total: 4.97s	remaining: 11.5s
# 400:	learn: 0.0108616	test: 0.0096243	best: 0.0096243 (400)	total: 6.6s	remaining: 9.85s
# 500:	learn: 0.0104240	test: 0.0095695	best: 0.0095694 (499)	total: 8.24s	remaining: 8.2s
# 600:	learn: 0.0100792	test: 0.0095300	best: 0.0095300 (600)	total: 9.86s	remaining: 6.54s
# 700:	learn: 0.0097485	test: 0.0094797	best: 0.0094783 (692)	total: 11.5s	remaining: 4.92s
# 800:	learn: 0.0095171	test: 0.0094410	best: 0.0094379 (784)	total: 13.2s	remaining: 3.27s
# 900:	learn: 0.0092950	test: 0.0094200	best: 0.0094192 (890)	total: 14.8s	remaining: 1.63s
# bestTest = 0.009410848316
# bestIteration = 909
# Shrink model to first 910 iterations.
#
# === Huấn luyện mô hình cho output 43/480 ===
# 0:	learn: 0.1701067	test: 0.1765998	best: 0.1765998 (0)	total: 34.4ms	remaining: 34.3s
# 100:	learn: 0.0759045	test: 0.0701609	best: 0.0701609 (100)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0720812	test: 0.0694788	best: 0.0694788 (200)	total: 3.42s	remaining: 13.6s
# 300:	learn: 0.0694805	test: 0.0691326	best: 0.0691326 (300)	total: 5.1s	remaining: 11.9s
# 400:	learn: 0.0674669	test: 0.0689093	best: 0.0689063 (390)	total: 6.78s	remaining: 10.1s
# 500:	learn: 0.0657661	test: 0.0687685	best: 0.0687662 (493)	total: 8.44s	remaining: 8.4s
# 600:	learn: 0.0642877	test: 0.0686680	best: 0.0686677 (595)	total: 10.1s	remaining: 6.71s
# 700:	learn: 0.0630767	test: 0.0685747	best: 0.0685747 (700)	total: 11.8s	remaining: 5.03s
# bestTest = 0.06854837346
# bestIteration = 713
# Shrink model to first 714 iterations.
#
# === Huấn luyện mô hình cho output 44/480 ===
# 0:	learn: 0.3324056	test: 0.3481824	best: 0.3481824 (0)	total: 32.8ms	remaining: 32.8s
# 100:	learn: 0.1012813	test: 0.1646486	best: 0.1620884 (53)	total: 1.79s	remaining: 16s
# bestTest = 0.1620883831
# bestIteration = 53
# Shrink model to first 54 iterations.
#
# === Huấn luyện mô hình cho output 45/480 ===
# 0:	learn: 0.1700919	test: 0.1765938	best: 0.1765938 (0)	total: 34.1ms	remaining: 34s
# 100:	learn: 0.0757869	test: 0.0700535	best: 0.0700526 (99)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0722384	test: 0.0694415	best: 0.0694415 (200)	total: 3.46s	remaining: 13.8s
# 300:	learn: 0.0694488	test: 0.0691960	best: 0.0691960 (300)	total: 5.15s	remaining: 12s
# 400:	learn: 0.0673819	test: 0.0689294	best: 0.0689278 (399)	total: 6.84s	remaining: 10.2s
# 500:	learn: 0.0657621	test: 0.0688539	best: 0.0688403 (480)	total: 8.54s	remaining: 8.51s
# 600:	learn: 0.0643521	test: 0.0686859	best: 0.0686859 (600)	total: 10.2s	remaining: 6.79s
# 700:	learn: 0.0631188	test: 0.0685987	best: 0.0685887 (695)	total: 11.9s	remaining: 5.09s
# 800:	learn: 0.0619483	test: 0.0684913	best: 0.0684744 (758)	total: 13.7s	remaining: 3.39s
# bestTest = 0.06847442171
# bestIteration = 758
# Shrink model to first 759 iterations.
#
# === Huấn luyện mô hình cho output 46/480 ===
# 0:	learn: 0.0586076	test: 0.0576120	best: 0.0576120 (0)	total: 32ms	remaining: 32s
# 100:	learn: 0.0293326	test: 0.0260947	best: 0.0260881 (98)	total: 1.79s	remaining: 16s
# 200:	learn: 0.0278485	test: 0.0259209	best: 0.0259209 (200)	total: 3.44s	remaining: 13.7s
# 300:	learn: 0.0268846	test: 0.0258114	best: 0.0258071 (298)	total: 5.1s	remaining: 11.8s
# 400:	learn: 0.0261068	test: 0.0257227	best: 0.0257202 (398)	total: 6.77s	remaining: 10.1s
# 500:	learn: 0.0254632	test: 0.0256521	best: 0.0256518 (480)	total: 8.45s	remaining: 8.42s
# 600:	learn: 0.0249513	test: 0.0255872	best: 0.0255845 (596)	total: 10.1s	remaining: 6.72s
# 700:	learn: 0.0244962	test: 0.0255417	best: 0.0255417 (700)	total: 11.8s	remaining: 5.03s
# 800:	learn: 0.0240837	test: 0.0255179	best: 0.0255179 (800)	total: 13.5s	remaining: 3.35s
# 900:	learn: 0.0237003	test: 0.0254996	best: 0.0254957 (851)	total: 15.2s	remaining: 1.67s
# bestTest = 0.02549567959
# bestIteration = 851
# Shrink model to first 852 iterations.
#
# === Huấn luyện mô hình cho output 47/480 ===
# 0:	learn: 0.0349556	test: 0.0332416	best: 0.0332416 (0)	total: 32.7ms	remaining: 32.7s
# 100:	learn: 0.0133940	test: 0.0100999	best: 0.0100955 (99)	total: 1.75s	remaining: 15.6s
# 200:	learn: 0.0123016	test: 0.0099123	best: 0.0099103 (190)	total: 3.35s	remaining: 13.3s
# 300:	learn: 0.0115575	test: 0.0097917	best: 0.0097917 (300)	total: 4.98s	remaining: 11.6s
# 400:	learn: 0.0110466	test: 0.0097397	best: 0.0097337 (391)	total: 6.58s	remaining: 9.84s
# 500:	learn: 0.0105674	test: 0.0097047	best: 0.0097036 (499)	total: 8.24s	remaining: 8.2s
# 600:	learn: 0.0101942	test: 0.0096585	best: 0.0096566 (598)	total: 9.89s	remaining: 6.57s
# bestTest = 0.009654032752
# bestIteration = 606
# Shrink model to first 607 iterations.
#
# === Huấn luyện mô hình cho output 48/480 ===
# 0:	learn: 0.1703051	test: 0.1762326	best: 0.1762326 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.0762133	test: 0.0703821	best: 0.0703821 (100)	total: 1.78s	remaining: 15.9s
# 200:	learn: 0.0723018	test: 0.0698050	best: 0.0697908 (197)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0697357	test: 0.0695336	best: 0.0695035 (285)	total: 5.09s	remaining: 11.8s
# 400:	learn: 0.0677398	test: 0.0693786	best: 0.0693662 (393)	total: 6.75s	remaining: 10.1s
# 500:	learn: 0.0660781	test: 0.0691864	best: 0.0691856 (499)	total: 8.46s	remaining: 8.42s
# 600:	learn: 0.0646058	test: 0.0691062	best: 0.0690942 (596)	total: 10.2s	remaining: 6.75s
# 700:	learn: 0.0633609	test: 0.0689719	best: 0.0689713 (697)	total: 11.8s	remaining: 5.04s
# 800:	learn: 0.0622608	test: 0.0689193	best: 0.0689170 (795)	total: 13.5s	remaining: 3.35s
# 900:	learn: 0.0612368	test: 0.0688770	best: 0.0688752 (899)	total: 15.2s	remaining: 1.67s
# bestTest = 0.06884542168
# bestIteration = 930
# Shrink model to first 931 iterations.
#
# === Huấn luyện mô hình cho output 49/480 ===
# 0:	learn: 0.3325553	test: 0.3482657	best: 0.3482657 (0)	total: 32.9ms	remaining: 32.9s
# 100:	learn: 0.1023073	test: 0.1596554	best: 0.1563694 (77)	total: 1.84s	remaining: 16.4s
# bestTest = 0.1559423547
# bestIteration = 120
# Shrink model to first 121 iterations.
#
# === Huấn luyện mô hình cho output 50/480 ===
# 0:	learn: 0.1702909	test: 0.1762269	best: 0.1762269 (0)	total: 34.2ms	remaining: 34.2s
# 100:	learn: 0.0763222	test: 0.0704208	best: 0.0704208 (100)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0722591	test: 0.0698112	best: 0.0698060 (197)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0696998	test: 0.0694836	best: 0.0694816 (293)	total: 5.11s	remaining: 11.9s
# 400:	learn: 0.0676244	test: 0.0693823	best: 0.0693785 (380)	total: 6.77s	remaining: 10.1s
# 500:	learn: 0.0659258	test: 0.0692632	best: 0.0692603 (499)	total: 8.47s	remaining: 8.44s
# 600:	learn: 0.0645279	test: 0.0691505	best: 0.0691503 (588)	total: 10.2s	remaining: 6.75s
# 700:	learn: 0.0632537	test: 0.0689970	best: 0.0689875 (694)	total: 11.9s	remaining: 5.07s
# bestTest = 0.06897858975
# bestIteration = 731
# Shrink model to first 732 iterations.
#
# === Huấn luyện mô hình cho output 51/480 ===
# 0:	learn: 0.0586739	test: 0.0575009	best: 0.0575009 (0)	total: 33.8ms	remaining: 33.8s
# 100:	learn: 0.0294278	test: 0.0261566	best: 0.0261551 (99)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0279814	test: 0.0259588	best: 0.0259583 (197)	total: 3.41s	remaining: 13.6s
# 300:	learn: 0.0269262	test: 0.0258865	best: 0.0258831 (293)	total: 5.09s	remaining: 11.8s
# bestTest = 0.02586182315
# bestIteration = 314
# Shrink model to first 315 iterations.
#
# === Huấn luyện mô hình cho output 52/480 ===
# 0:	learn: 0.0349786	test: 0.0331784	best: 0.0331784 (0)	total: 34.4ms	remaining: 34.4s
# 100:	learn: 0.0135180	test: 0.0101211	best: 0.0101211 (100)	total: 1.74s	remaining: 15.5s
# 200:	learn: 0.0124424	test: 0.0099559	best: 0.0099427 (186)	total: 3.34s	remaining: 13.3s
# 300:	learn: 0.0117192	test: 0.0097980	best: 0.0097980 (300)	total: 4.95s	remaining: 11.5s
# 400:	learn: 0.0111621	test: 0.0097518	best: 0.0097437 (369)	total: 6.58s	remaining: 9.83s
# bestTest = 0.00974365817
# bestIteration = 369
# Shrink model to first 370 iterations.
#
# === Huấn luyện mô hình cho output 53/480 ===
# 0:	learn: 0.1702663	test: 0.1756544	best: 0.1756544 (0)	total: 32.6ms	remaining: 32.6s
# 100:	learn: 0.0763110	test: 0.0702821	best: 0.0702821 (100)	total: 1.82s	remaining: 16.2s
# 200:	learn: 0.0726129	test: 0.0697998	best: 0.0697998 (200)	total: 3.48s	remaining: 13.8s
# 300:	learn: 0.0700072	test: 0.0695369	best: 0.0695364 (299)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0679319	test: 0.0693543	best: 0.0693421 (382)	total: 6.8s	remaining: 10.2s
# 500:	learn: 0.0662112	test: 0.0691685	best: 0.0691566 (481)	total: 8.49s	remaining: 8.45s
# 600:	learn: 0.0648481	test: 0.0690909	best: 0.0690909 (600)	total: 10.2s	remaining: 6.75s
# 700:	learn: 0.0635855	test: 0.0690359	best: 0.0690185 (655)	total: 11.9s	remaining: 5.06s
# bestTest = 0.06901847578
# bestIteration = 655
# Shrink model to first 656 iterations.
#
# === Huấn luyện mô hình cho output 54/480 ===
# 0:	learn: 0.3325504	test: 0.3493684	best: 0.3493684 (0)	total: 32.6ms	remaining: 32.6s
# 100:	learn: 0.1024851	test: 0.1702667	best: 0.1691643 (92)	total: 1.81s	remaining: 16.2s
# bestTest = 0.1691643254
# bestIteration = 92
# Shrink model to first 93 iterations.
#
# === Huấn luyện mô hình cho output 55/480 ===
# 0:	learn: 0.1702517	test: 0.1756484	best: 0.1756484 (0)	total: 32.4ms	remaining: 32.4s
# 100:	learn: 0.0763601	test: 0.0701826	best: 0.0701805 (98)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0726088	test: 0.0696609	best: 0.0696572 (198)	total: 3.46s	remaining: 13.7s
# 300:	learn: 0.0700722	test: 0.0693619	best: 0.0693619 (300)	total: 5.1s	remaining: 11.8s
# 400:	learn: 0.0680099	test: 0.0691936	best: 0.0691792 (382)	total: 6.78s	remaining: 10.1s
# 500:	learn: 0.0662964	test: 0.0689725	best: 0.0689522 (488)	total: 8.43s	remaining: 8.4s
# 600:	learn: 0.0648011	test: 0.0688788	best: 0.0688788 (600)	total: 10.1s	remaining: 6.71s
# bestTest = 0.06880747537
# bestIteration = 648
# Shrink model to first 649 iterations.
#
# === Huấn luyện mô hình cho output 56/480 ===
# 0:	learn: 0.0587065	test: 0.0572836	best: 0.0572836 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.0295313	test: 0.0262941	best: 0.0262941 (100)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0280704	test: 0.0261404	best: 0.0261404 (200)	total: 3.42s	remaining: 13.6s
# 300:	learn: 0.0270706	test: 0.0260404	best: 0.0260404 (300)	total: 5.08s	remaining: 11.8s
# 400:	learn: 0.0262655	test: 0.0259709	best: 0.0259709 (400)	total: 6.74s	remaining: 10.1s
# 500:	learn: 0.0256482	test: 0.0258942	best: 0.0258942 (500)	total: 8.39s	remaining: 8.35s
# 600:	learn: 0.0251188	test: 0.0258397	best: 0.0258372 (587)	total: 10.1s	remaining: 6.68s
# 700:	learn: 0.0246502	test: 0.0257841	best: 0.0257830 (698)	total: 11.8s	remaining: 5.02s
# 800:	learn: 0.0242403	test: 0.0257710	best: 0.0257710 (800)	total: 13.5s	remaining: 3.35s
# 900:	learn: 0.0238760	test: 0.0257458	best: 0.0257458 (900)	total: 15.1s	remaining: 1.66s
# 999:	learn: 0.0235331	test: 0.0257172	best: 0.0257172 (999)	total: 16.8s	remaining: 0us
# bestTest = 0.02571717594
# bestIteration = 999
#
# === Huấn luyện mô hình cho output 57/480 ===
# 0:	learn: 0.0350206	test: 0.0331757	best: 0.0331757 (0)	total: 34.4ms	remaining: 34.4s
# 100:	learn: 0.0136301	test: 0.0102831	best: 0.0102820 (99)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0125107	test: 0.0101149	best: 0.0101149 (200)	total: 3.4s	remaining: 13.5s
# 300:	learn: 0.0118333	test: 0.0100342	best: 0.0100342 (300)	total: 5.02s	remaining: 11.7s
# 400:	learn: 0.0112138	test: 0.0099635	best: 0.0099548 (387)	total: 6.66s	remaining: 9.95s
# 500:	learn: 0.0107594	test: 0.0099061	best: 0.0099061 (500)	total: 8.31s	remaining: 8.28s
# 600:	learn: 0.0103744	test: 0.0098566	best: 0.0098560 (599)	total: 9.97s	remaining: 6.62s
# 700:	learn: 0.0100660	test: 0.0098138	best: 0.0098106 (674)	total: 11.6s	remaining: 4.96s
# 800:	learn: 0.0098069	test: 0.0097743	best: 0.0097655 (782)	total: 13.3s	remaining: 3.29s
# 900:	learn: 0.0095565	test: 0.0097259	best: 0.0097259 (900)	total: 14.9s	remaining: 1.64s
# 999:	learn: 0.0093357	test: 0.0096809	best: 0.0096809 (999)	total: 16.6s	remaining: 0us
# bestTest = 0.00968094072
# bestIteration = 999
#
# === Huấn luyện mô hình cho output 58/480 ===
# 0:	learn: 0.1703770	test: 0.1749311	best: 0.1749311 (0)	total: 31.8ms	remaining: 31.7s
# 100:	learn: 0.0764734	test: 0.0703766	best: 0.0703766 (100)	total: 1.79s	remaining: 15.9s
# 200:	learn: 0.0728558	test: 0.0698074	best: 0.0697882 (194)	total: 3.46s	remaining: 13.8s
# 300:	learn: 0.0702692	test: 0.0694813	best: 0.0694813 (300)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0680885	test: 0.0692372	best: 0.0692335 (397)	total: 6.79s	remaining: 10.1s
# 500:	learn: 0.0663975	test: 0.0690191	best: 0.0690191 (500)	total: 8.46s	remaining: 8.43s
# 600:	learn: 0.0649258	test: 0.0689480	best: 0.0689186 (580)	total: 10.2s	remaining: 6.74s
# bestTest = 0.0689186126
# bestIteration = 580
# Shrink model to first 581 iterations.
#
# === Huấn luyện mô hình cho output 59/480 ===
# 0:	learn: 0.3323879	test: 0.3493901	best: 0.3493901 (0)	total: 32.6ms	remaining: 32.6s
# 100:	learn: 0.1038573	test: 0.1698610	best: 0.1627795 (75)	total: 1.83s	remaining: 16.3s
# bestTest = 0.1627794508
# bestIteration = 75
# Shrink model to first 76 iterations.
#
# === Huấn luyện mô hình cho output 60/480 ===
# 0:	learn: 0.1703868	test: 0.1748424	best: 0.1748424 (0)	total: 34ms	remaining: 34s
# 100:	learn: 0.0765983	test: 0.0704175	best: 0.0704175 (100)	total: 1.79s	remaining: 16s
# 200:	learn: 0.0729972	test: 0.0697635	best: 0.0697635 (200)	total: 3.45s	remaining: 13.7s
# 300:	learn: 0.0702981	test: 0.0694506	best: 0.0694506 (300)	total: 5.12s	remaining: 11.9s
# 400:	learn: 0.0681571	test: 0.0692289	best: 0.0692208 (381)	total: 6.82s	remaining: 10.2s
# 500:	learn: 0.0664522	test: 0.0691245	best: 0.0691219 (498)	total: 8.53s	remaining: 8.49s
# bestTest = 0.06909037129
# bestIteration = 530
# Shrink model to first 531 iterations.
#
# === Huấn luyện mô hình cho output 61/480 ===
# 0:	learn: 0.0587733	test: 0.0572109	best: 0.0572109 (0)	total: 33.7ms	remaining: 33.7s
# 100:	learn: 0.0297360	test: 0.0262647	best: 0.0262647 (100)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.0283107	test: 0.0261002	best: 0.0261002 (200)	total: 3.43s	remaining: 13.6s
# 300:	learn: 0.0272508	test: 0.0260352	best: 0.0260327 (283)	total: 5.09s	remaining: 11.8s
# 400:	learn: 0.0264596	test: 0.0259522	best: 0.0259489 (399)	total: 6.79s	remaining: 10.2s
# 500:	learn: 0.0258169	test: 0.0258814	best: 0.0258814 (500)	total: 8.48s	remaining: 8.45s
# 600:	learn: 0.0252794	test: 0.0258367	best: 0.0258367 (600)	total: 10.2s	remaining: 6.76s
# 700:	learn: 0.0248017	test: 0.0257864	best: 0.0257817 (692)	total: 11.9s	remaining: 5.05s
# bestTest = 0.02578165732
# bestIteration = 692
# ...
# 100:	learn: 0.0804594	test: 0.0796409	best: 0.0796105 (90)	total: 1.76s	remaining: 15.7s
# 200:	learn: 0.0772964	test: 0.0796238	best: 0.0795668 (161)	total: 3.35s	remaining: 13.3s
# bestTest = 0.07956676975
# bestIteration = 161
# Shrink model to first 162 iterations.
#
# === Huấn luyện mô hình cho output 429/480 ===
# 0:	learn: 0.3338803	test: 0.3632659	best: 0.3632659 (0)	total: 32.7ms	remaining: 32.6s
# bestTest = 0.1997105826
# bestIteration = 23
# Shrink model to first 24 iterations.
#
# === Huấn luyện mô hình cho output 430/480 ===
# 0:	learn: 0.1702571	test: 0.1792641	best: 0.1792641 (0)	total: 32ms	remaining: 32s
# 100:	learn: 0.0803196	test: 0.0795837	best: 0.0795456 (93)	total: 1.78s	remaining: 15.8s
# 200:	learn: 0.0771227	test: 0.0794924	best: 0.0794257 (170)	total: 3.38s	remaining: 13.5s
# bestTest = 0.07942567125
# bestIteration = 170
# Shrink model to first 171 iterations.
#
# === Huấn luyện mô hình cho output 431/480 ===
# 0:	learn: 0.0587033	test: 0.0585483	best: 0.0585483 (0)	total: 34.2ms	remaining: 34.2s
# 100:	learn: 0.0308947	test: 0.0300559	best: 0.0300081 (59)	total: 1.77s	remaining: 15.8s
# bestTest = 0.03000810442
# bestIteration = 59
# Shrink model to first 60 iterations.
#
# === Huấn luyện mô hình cho output 432/480 ===
# 0:	learn: 0.0347399	test: 0.0351917	best: 0.0351917 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.0146608	test: 0.0142678	best: 0.0142493 (89)	total: 1.73s	remaining: 15.4s
# bestTest = 0.01424933867
# bestIteration = 89
# Shrink model to first 90 iterations.
#
# === Huấn luyện mô hình cho output 433/480 ===
# 0:	learn: 0.1701796	test: 0.1794006	best: 0.1794006 (0)	total: 33ms	remaining: 32.9s
# 100:	learn: 0.0804608	test: 0.0794859	best: 0.0794567 (96)	total: 1.76s	remaining: 15.7s
# 200:	learn: 0.0773206	test: 0.0794673	best: 0.0794070 (181)	total: 3.4s	remaining: 13.5s
# bestTest = 0.07940699996
# bestIteration = 181
# Shrink model to first 182 iterations.
#
# === Huấn luyện mô hình cho output 434/480 ===
# 0:	learn: 0.3342922	test: 0.3640040	best: 0.3640040 (0)	total: 34.6ms	remaining: 34.5s
# bestTest = 0.2076548263
# bestIteration = 28
# Shrink model to first 29 iterations.
#
# === Huấn luyện mô hình cho output 435/480 ===
# 0:	learn: 0.1701705	test: 0.1794022	best: 0.1794022 (0)	total: 32.6ms	remaining: 32.5s
# 100:	learn: 0.0802406	test: 0.0797782	best: 0.0797702 (98)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07974682919
# bestIteration = 132
# Shrink model to first 133 iterations.
#
# === Huấn luyện mô hình cho output 436/480 ===
# 0:	learn: 0.0586924	test: 0.0586455	best: 0.0586455 (0)	total: 34.1ms	remaining: 34.1s
# 100:	learn: 0.0309142	test: 0.0300496	best: 0.0300253 (68)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03002526048
# bestIteration = 68
# Shrink model to first 69 iterations.
#
# === Huấn luyện mô hình cho output 437/480 ===
# 0:	learn: 0.0347620	test: 0.0352116	best: 0.0352116 (0)	total: 34.8ms	remaining: 34.8s
# 100:	learn: 0.0146829	test: 0.0143670	best: 0.0142761 (54)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01427610399
# bestIteration = 54
# Shrink model to first 55 iterations.
#
# === Huấn luyện mô hình cho output 438/480 ===
# 0:	learn: 0.1702346	test: 0.1798433	best: 0.1798433 (0)	total: 31.3ms	remaining: 31.3s
# 100:	learn: 0.0803752	test: 0.0796669	best: 0.0796483 (89)	total: 1.81s	remaining: 16.1s
# bestTest = 0.07962234698
# bestIteration = 145
# Shrink model to first 146 iterations.
#
# === Huấn luyện mô hình cho output 439/480 ===
# 0:	learn: 0.3336783	test: 0.3611903	best: 0.3611903 (0)	total: 32.6ms	remaining: 32.6s
# 100:	learn: 0.1328896	test: 0.1996465	best: 0.1983219 (95)	total: 1.82s	remaining: 16.2s
# bestTest = 0.1983219013
# bestIteration = 95
# Shrink model to first 96 iterations.
#
# === Huấn luyện mô hình cho output 440/480 ===
# 0:	learn: 0.1702183	test: 0.1798386	best: 0.1798386 (0)	total: 32ms	remaining: 31.9s
# 100:	learn: 0.0803887	test: 0.0797008	best: 0.0796634 (84)	total: 1.76s	remaining: 15.7s
# bestTest = 0.07966340201
# bestIteration = 84
# Shrink model to first 85 iterations.
#
# === Huấn luyện mô hình cho output 441/480 ===
# 0:	learn: 0.0586851	test: 0.0587970	best: 0.0587970 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.0308881	test: 0.0300478	best: 0.0300350 (82)	total: 1.76s	remaining: 15.7s
# bestTest = 0.03003501659
# bestIteration = 82
# Shrink model to first 83 iterations.
#
# === Huấn luyện mô hình cho output 442/480 ===
# 0:	learn: 0.0347359	test: 0.0352450	best: 0.0352450 (0)	total: 32.6ms	remaining: 32.5s
# 100:	learn: 0.0146805	test: 0.0142428	best: 0.0142005 (56)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01420053822
# bestIteration = 56
# Shrink model to first 57 iterations.
#
# === Huấn luyện mô hình cho output 443/480 ===
# 0:	learn: 0.1702477	test: 0.1801964	best: 0.1801964 (0)	total: 32.4ms	remaining: 32.4s
# 100:	learn: 0.0805052	test: 0.0796872	best: 0.0796342 (70)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07963417954
# bestIteration = 70
# Shrink model to first 71 iterations.
#
# === Huấn luyện mô hình cho output 444/480 ===
# 0:	learn: 0.3339202	test: 0.3637062	best: 0.3637062 (0)	total: 33.1ms	remaining: 33.1s
# bestTest = 0.1900076905
# bestIteration = 31
# Shrink model to first 32 iterations.
#
# === Huấn luyện mô hình cho output 445/480 ===
# 0:	learn: 0.1702264	test: 0.1801927	best: 0.1801927 (0)	total: 33ms	remaining: 33s
# 100:	learn: 0.0804937	test: 0.0799065	best: 0.0798613 (70)	total: 1.8s	remaining: 16.1s
# bestTest = 0.07986129587
# bestIteration = 70
# Shrink model to first 71 iterations.
#
# === Huấn luyện mô hình cho output 446/480 ===
# 0:	learn: 0.0587041	test: 0.0589330	best: 0.0589330 (0)	total: 36ms	remaining: 35.9s
# 100:	learn: 0.0309551	test: 0.0301596	best: 0.0301269 (70)	total: 1.76s	remaining: 15.7s
# bestTest = 0.03012690115
# bestIteration = 70
# Shrink model to first 71 iterations.
#
# === Huấn luyện mô hình cho output 447/480 ===
# 0:	learn: 0.0347413	test: 0.0352530	best: 0.0352530 (0)	total: 32.9ms	remaining: 32.9s
# 100:	learn: 0.0146968	test: 0.0142889	best: 0.0142492 (63)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01424924813
# bestIteration = 63
# Shrink model to first 64 iterations.
#
# === Huấn luyện mô hình cho output 448/480 ===
# 0:	learn: 0.1702443	test: 0.1806534	best: 0.1806534 (0)	total: 32.6ms	remaining: 32.6s
# 100:	learn: 0.0804629	test: 0.0798605	best: 0.0798605 (100)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07983467693
# bestIteration = 130
# Shrink model to first 131 iterations.
#
# === Huấn luyện mô hình cho output 449/480 ===
# 0:	learn: 0.3340645	test: 0.3626174	best: 0.3626174 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.1330373	test: 0.1887841	best: 0.1880448 (90)	total: 1.82s	remaining: 16.2s
# bestTest = 0.188044777
# bestIteration = 90
# Shrink model to first 91 iterations.
#
# === Huấn luyện mô hình cho output 450/480 ===
# 0:	learn: 0.1702270	test: 0.1806480	best: 0.1806480 (0)	total: 32.7ms	remaining: 32.7s
# 100:	learn: 0.0804940	test: 0.0799076	best: 0.0798702 (84)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07979853887
# bestIteration = 133
# Shrink model to first 134 iterations.
#
# === Huấn luyện mô hình cho output 451/480 ===
# 0:	learn: 0.0586669	test: 0.0590597	best: 0.0590597 (0)	total: 32.5ms	remaining: 32.5s
# 100:	learn: 0.0309402	test: 0.0301124	best: 0.0300578 (65)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03005782068
# bestIteration = 65
# Shrink model to first 66 iterations.
#
# === Huấn luyện mô hình cho output 452/480 ===
# 0:	learn: 0.0347416	test: 0.0352432	best: 0.0352432 (0)	total: 33ms	remaining: 33s
# 100:	learn: 0.0147526	test: 0.0143261	best: 0.0142821 (60)	total: 1.71s	remaining: 15.2s
# bestTest = 0.01428214351
# bestIteration = 60
# Shrink model to first 61 iterations.
#
# === Huấn luyện mô hình cho output 453/480 ===
# 0:	learn: 0.1701713	test: 0.1809505	best: 0.1809505 (0)	total: 32.1ms	remaining: 32s
# 100:	learn: 0.0806449	test: 0.0798970	best: 0.0798796 (93)	total: 1.79s	remaining: 16s
# bestTest = 0.07987959107
# bestIteration = 93
# Shrink model to first 94 iterations.
#
# === Huấn luyện mô hình cho output 454/480 ===
# 0:	learn: 0.3338123	test: 0.3617371	best: 0.3617371 (0)	total: 34.5ms	remaining: 34.5s
# 100:	learn: 0.1332386	test: 0.1931214	best: 0.1925733 (89)	total: 1.81s	remaining: 16.1s
# 200:	learn: 0.1267419	test: 0.1916536	best: 0.1916536 (200)	total: 3.44s	remaining: 13.7s
# 300:	learn: 0.1226049	test: 0.1909343	best: 0.1908874 (295)	total: 5.08s	remaining: 11.8s
# bestTest = 0.1904986466
# bestIteration = 308
# Shrink model to first 309 iterations.
#
# === Huấn luyện mô hình cho output 455/480 ===
# 0:	learn: 0.1701841	test: 0.1809654	best: 0.1809654 (0)	total: 31.8ms	remaining: 31.8s
# 100:	learn: 0.0804846	test: 0.0799138	best: 0.0798302 (82)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07983018355
# bestIteration = 82
# Shrink model to first 83 iterations.
#
# === Huấn luyện mô hình cho output 456/480 ===
# 0:	learn: 0.0586825	test: 0.0592115	best: 0.0592115 (0)	total: 33.3ms	remaining: 33.2s
# 100:	learn: 0.0308769	test: 0.0300605	best: 0.0300158 (83)	total: 1.76s	remaining: 15.7s
# bestTest = 0.03001577629
# bestIteration = 83
# Shrink model to first 84 iterations.
#
# === Huấn luyện mô hình cho output 457/480 ===
# 0:	learn: 0.0347391	test: 0.0352742	best: 0.0352742 (0)	total: 33.4ms	remaining: 33.4s
# 100:	learn: 0.0146679	test: 0.0142874	best: 0.0142819 (57)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01428194879
# bestIteration = 57
# Shrink model to first 58 iterations.
#
# === Huấn luyện mô hình cho output 458/480 ===
# 0:	learn: 0.1701929	test: 0.1813137	best: 0.1813137 (0)	total: 32.8ms	remaining: 32.7s
# 100:	learn: 0.0805358	test: 0.0799246	best: 0.0798474 (90)	total: 1.79s	remaining: 15.9s
# bestTest = 0.07984738861
# bestIteration = 90
# Shrink model to first 91 iterations.
#
# === Huấn luyện mô hình cho output 459/480 ===
# 0:	learn: 0.3338992	test: 0.3627355	best: 0.3627355 (0)	total: 32.4ms	remaining: 32.3s
# bestTest = 0.1985733681
# bestIteration = 41
# Shrink model to first 42 iterations.
#
# === Huấn luyện mô hình cho output 460/480 ===
# 0:	learn: 0.1701757	test: 0.1813084	best: 0.1813084 (0)	total: 32ms	remaining: 32s
# 100:	learn: 0.0805203	test: 0.0799810	best: 0.0798517 (67)	total: 1.79s	remaining: 15.9s
# bestTest = 0.07985165698
# bestIteration = 67
# Shrink model to first 68 iterations.
#
# === Huấn luyện mô hình cho output 461/480 ===
# 0:	learn: 0.0586669	test: 0.0593570	best: 0.0593570 (0)	total: 33.9ms	remaining: 33.9s
# 100:	learn: 0.0308393	test: 0.0301247	best: 0.0300906 (65)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03009063433
# bestIteration = 65
# Shrink model to first 66 iterations.
#
# === Huấn luyện mô hình cho output 462/480 ===
# 0:	learn: 0.0347505	test: 0.0352554	best: 0.0352554 (0)	total: 33.7ms	remaining: 33.6s
# 100:	learn: 0.0147428	test: 0.0142617	best: 0.0142265 (69)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01422651724
# bestIteration = 69
# Shrink model to first 70 iterations.
#
# === Huấn luyện mô hình cho output 463/480 ===
# 0:	learn: 0.1702237	test: 0.1818396	best: 0.1818396 (0)	total: 31.6ms	remaining: 31.6s
# 100:	learn: 0.0803167	test: 0.0800964	best: 0.0800153 (88)	total: 1.79s	remaining: 15.9s
# bestTest = 0.08001532881
# bestIteration = 88
# Shrink model to first 89 iterations.
#
# === Huấn luyện mô hình cho output 464/480 ===
# 0:	learn: 0.3337058	test: 0.3619855	best: 0.3619855 (0)	total: 32.7ms	remaining: 32.6s
# bestTest = 0.1941747673
# bestIteration = 40
# Shrink model to first 41 iterations.
#
# === Huấn luyện mô hình cho output 465/480 ===
# 0:	learn: 0.1702070	test: 0.1818346	best: 0.1818346 (0)	total: 31.6ms	remaining: 31.5s
# 100:	learn: 0.0803609	test: 0.0799745	best: 0.0799745 (100)	total: 1.78s	remaining: 15.9s
# bestTest = 0.07997166392
# bestIteration = 110
# Shrink model to first 111 iterations.
#
# === Huấn luyện mô hình cho output 466/480 ===
# 0:	learn: 0.0586897	test: 0.0595278	best: 0.0595278 (0)	total: 33.5ms	remaining: 33.4s
# 100:	learn: 0.0309309	test: 0.0301809	best: 0.0301500 (81)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03014998567
# bestIteration = 81
# Shrink model to first 82 iterations.
#
# === Huấn luyện mô hình cho output 467/480 ===
# 0:	learn: 0.0347621	test: 0.0352864	best: 0.0352864 (0)	total: 33ms	remaining: 33s
# 100:	learn: 0.0147360	test: 0.0143502	best: 0.0142969 (79)	total: 1.73s	remaining: 15.4s
# bestTest = 0.01429687168
# bestIteration = 79
# Shrink model to first 80 iterations.
#
# === Huấn luyện mô hình cho output 468/480 ===
# 0:	learn: 0.1703639	test: 0.1824116	best: 0.1824116 (0)	total: 34.2ms	remaining: 34.2s
# 100:	learn: 0.0805783	test: 0.0802404	best: 0.0801632 (63)	total: 1.8s	remaining: 16s
# bestTest = 0.08016322926
# bestIteration = 63
# Shrink model to first 64 iterations.
#
# === Huấn luyện mô hình cho output 469/480 ===
# 0:	learn: 0.3338329	test: 0.3615268	best: 0.3615268 (0)	total: 32.5ms	remaining: 32.5s
# bestTest = 0.1985898243
# bestIteration = 23
# Shrink model to first 24 iterations.
#
# === Huấn luyện mô hình cho output 470/480 ===
# 0:	learn: 0.1703462	test: 0.1824058	best: 0.1824058 (0)	total: 34.1ms	remaining: 34s
# 100:	learn: 0.0805551	test: 0.0802923	best: 0.0801660 (72)	total: 1.78s	remaining: 15.9s
# bestTest = 0.08016604172
# bestIteration = 72
# Shrink model to first 73 iterations.
#
# === Huấn luyện mô hình cho output 471/480 ===
# 0:	learn: 0.0586694	test: 0.0596724	best: 0.0596724 (0)	total: 32.1ms	remaining: 32.1s
# 100:	learn: 0.0309777	test: 0.0302776	best: 0.0302385 (70)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03023846715
# bestIteration = 70
# Shrink model to first 71 iterations.
#
# === Huấn luyện mô hình cho output 472/480 ===
# 0:	learn: 0.0347613	test: 0.0352855	best: 0.0352855 (0)	total: 33.5ms	remaining: 33.4s
# 100:	learn: 0.0147199	test: 0.0142936	best: 0.0142761 (81)	total: 1.74s	remaining: 15.5s
# bestTest = 0.01427607889
# bestIteration = 81
# Shrink model to first 82 iterations.
#
# === Huấn luyện mô hình cho output 473/480 ===
# 0:	learn: 0.1702802	test: 0.1825200	best: 0.1825200 (0)	total: 32.2ms	remaining: 32.2s
# 100:	learn: 0.0806840	test: 0.0802802	best: 0.0802792 (99)	total: 1.8s	remaining: 16.1s
# bestTest = 0.08026891336
# bestIteration = 103
# Shrink model to first 104 iterations.
#
# === Huấn luyện mô hình cho output 474/480 ===
# 0:	learn: 0.3340879	test: 0.3632315	best: 0.3632315 (0)	total: 33.4ms	remaining: 33.4s
# bestTest = 0.1986312776
# bestIteration = 33
# Shrink model to first 34 iterations.
#
# === Huấn luyện mô hình cho output 475/480 ===
# 0:	learn: 0.1702631	test: 0.1825148	best: 0.1825148 (0)	total: 32ms	remaining: 31.9s
# 100:	learn: 0.0807766	test: 0.0801113	best: 0.0800856 (85)	total: 1.79s	remaining: 15.9s
# bestTest = 0.08008563455
# bestIteration = 85
# Shrink model to first 86 iterations.
#
# === Huấn luyện mô hình cho output 476/480 ===
# 0:	learn: 0.0586925	test: 0.0598370	best: 0.0598370 (0)	total: 33.5ms	remaining: 33.4s
# 100:	learn: 0.0309796	test: 0.0303239	best: 0.0302664 (53)	total: 1.75s	remaining: 15.6s
# bestTest = 0.03026639267
# bestIteration = 53
# Shrink model to first 54 iterations.
#
# === Huấn luyện mô hình cho output 477/480 ===
# 0:	learn: 0.0347752	test: 0.0352960	best: 0.0352960 (0)	total: 33.2ms	remaining: 33.2s
# 100:	learn: 0.0147169	test: 0.0143620	best: 0.0143460 (81)	total: 1.7s	remaining: 15.2s
# bestTest = 0.01434598694
# bestIteration = 81
# Shrink model to first 82 iterations.
#
# === Huấn luyện mô hình cho output 478/480 ===
# 0:	learn: 0.1703230	test: 0.1829079	best: 0.1829079 (0)	total: 33ms	remaining: 32.9s
# 100:	learn: 0.0808617	test: 0.0803832	best: 0.0803031 (79)	total: 1.76s	remaining: 15.7s
# bestTest = 0.08030311465
# bestIteration = 79
# Shrink model to first 80 iterations.
#
# === Huấn luyện mô hình cho output 479/480 ===
# 0:	learn: 0.3340820	test: 0.3645063	best: 0.3645063 (0)	total: 32.7ms	remaining: 32.7s
# 100:	learn: 0.1346918	test: 0.1926005	best: 0.1924289 (96)	total: 1.8s	remaining: 16s
# 200:	learn: 0.1281320	test: 0.1896131	best: 0.1896069 (198)	total: 3.43s	remaining: 13.6s
# bestTest = 0.1882133523
# bestIteration = 217
# Shrink model to first 218 iterations.
#
# === Huấn luyện mô hình cho output 480/480 ===
# 0:	learn: 0.1703064	test: 0.1829030	best: 0.1829030 (0)	total: 32ms	remaining: 31.9s
# 100:	learn: 0.0809188	test: 0.0803633	best: 0.0802955 (72)	total: 1.8s	remaining: 16s
# bestTest = 0.08029554831
# bestIteration = 72
# Shrink model to first 73 iterations.
#
# Hoàn tất huấn luyện 480 mô hình CatBoost trên GPU!
# Đã lưu file 'catboost_model_gpu.joblib'

# %%
# --- Cell 9: Đánh giá trên tập Test ---
if 'catboost_models' in locals():
    print("--- Đánh giá CatBoost trên tập Test ---")
    
    # Dự đoán bằng cách lặp qua từng mô hình con
    y_pred_list = [model.predict(X_test_flat) for model in catboost_models]
    # Ghép các kết quả dự đoán lại
    y_pred_flat = np.stack(y_pred_list, axis=1)

    y_test_flat = y_test.reshape(y_test.shape[0], -1)

    # Tính toán lỗi
    test_loss_mse = mean_squared_error(y_test_flat, y_pred_flat)
    test_metric_mae = mean_absolute_error(y_test_flat, y_pred_flat)

    print(f"  Test Loss (MSE): {test_loss_mse:.6f}")
    print(f"  Test MAE (Mean Absolute Error): {test_metric_mae:.6f}")
    
    # Lưu loss vào file
    with open('catboost_loss.txt', 'w') as f:
        f.write(f"MSE: {test_loss_mse}\n")
        f.write(f"MAE: {test_metric_mae}\n")
    print("Đã lưu loss vào file 'catboost_loss.txt'.")
else:
    print("Lỗi: Mô hình CatBoost (catboost_models) chưa được huấn luyện.")
# Out:
# --- Đánh giá CatBoost trên tập Test ---
#   Test Loss (MSE): 0.007787
#   Test MAE (Mean Absolute Error): 0.034272
# Đã lưu loss vào file 'catboost_loss.txt'.

# %%
# --- Cell 10: So sánh kết quả dự đoán với giá trị thực tế ---
if 'catboost_models' in locals() and 'X_test' in locals() and 'scaler' in locals():
    print("--- Trực quan hóa kết quả dự đoán CatBoost trên tập Test ---")
    num_samples_to_plot = min(5, X_test.shape[0])
    if num_samples_to_plot > 0:
        # Lấy subset của test data
        X_test_subset_flat = X_test_flat[:num_samples_to_plot]

        # Dự đoán với subset
        y_pred_list = [model.predict(X_test_subset_flat) for model in catboost_models]
        y_pred_flat = np.stack(y_pred_list, axis=1)
        y_pred_scaled = y_pred_flat.reshape(num_samples_to_plot, OUTPUT_STEPS, N_FEATURES)

        y_test_subset = y_test[:num_samples_to_plot]

        y_true_reshaped = y_test_subset.reshape(-1, N_FEATURES)
        y_true_original = scaler.inverse_transform(y_true_reshaped)
        y_true_original = y_true_original.reshape(num_samples_to_plot, OUTPUT_STEPS, N_FEATURES)

        y_pred_reshaped = y_pred_scaled.reshape(-1, N_FEATURES)
        y_pred_original = scaler.inverse_transform(y_pred_reshaped)
        y_pred_original = y_pred_original.reshape(num_samples_to_plot, OUTPUT_STEPS, N_FEATURES)

        for i in range(num_samples_to_plot):
            print(f"\n--- So sánh Mẫu #{i+1} ---")
            fig, axes = plt.subplots(N_FEATURES, 1, figsize=(15, 5 * N_FEATURES), sharex=True)
            if N_FEATURES == 1: axes = [axes]

            for j, feature_name in enumerate(FEATURE_COLS):
                ax = axes[j]
                ax.plot(y_true_original[i, :, j], label=f'Thực tế ({feature_name})', color='blue', marker='o', linestyle='-')
                ax.plot(y_pred_original[i, :, j], label=f'Dự đoán ({feature_name})', color='red', marker='x', linestyle='--')
                ax.set_title(f'Dự đoán {feature_name} (Mẫu #{i+1})')
                ax.set_xlabel('Bước thời gian (15 phút)')
                ax.set_ylabel(f'Giá trị {feature_name}')
                ax.legend()
                ax.grid(True)
            
            plt.tight_layout()
            plt.show()
    else:
        print("Không có mẫu nào trong X_test để dự đoán.")
else:
    print("Lỗi: Không thể trực quan hóa.")
# Out:
# --- Trực quan hóa kết quả dự đoán CatBoost trên tập Test ---
#
# --- So sánh Mẫu #1 ---
# --- So sánh Mẫu #2 ---
# --- So sánh Mẫu #3 ---
# --- So sánh Mẫu #4 ---
# --- So sánh Mẫu #5 ---
